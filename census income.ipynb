# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('D:\dataset1-master\census_income.csv')
data.head()
# Out:
#    Age          Workclass  Fnlwgt   Education  Education_num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         Marital_status          Occupation    Relationship    Race      Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    Capital_gain  Capital_loss  Hours_per_week  Native_country  Income
# 0             0             0              13   United-States   <=50K
# ...

# %%
data.shape
# Out:
# (32560, 15)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32560 non-null  int64
#  1   Workclass       32560 non-null  object
#  2   Fnlwgt          32560 non-null  int64
#  3   Education       32560 non-null  object
#  4   Education_num   32560 non-null  int64
#  5   Marital_status  32560 non-null  object
#  6   Occupation      32560 non-null  object
#  7   Relationship    32560 non-null  object
#  8   Race            32560 non-null  object
#  9   Sex             32560 non-null  object
#  10  Capital_gain    32560 non-null  int64
#  11  Capital_loss    32560 non-null  int64
#  12  Hours_per_week  32560 non-null  int64
#  13  Native_country  32560 non-null  object
#  14  Income          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
#lets check for nulls
data.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %%
#as there are no nulls lets move further
data.dtypes
# Out:
# Age                int64
# Workclass         object
# Fnlwgt             int64
# Education         object
# Education_num      int64
# Marital_status    object
# Occupation        object
# Relationship      object
# Race              object
# Sex               object
# Capital_gain       int64
# Capital_loss       int64
# Hours_per_week     int64
# Native_country    object
# Income            object
# dtype: object

# %%
#lets check zeros 
#lets check
count=(data==0).sum()
count
# Out:
# Age                   0
# Workclass             0
# Fnlwgt                0
# Education             0
# Education_num         0
# Marital_status        0
# Occupation            0
# Relationship          0
# Race                  0
# Sex                   0
# Capital_gain      29849
# Capital_loss      31041
# Hours_per_week        0
# Native_country        0
# Income                0
# dtype: int64

# %%
# lets deal with zero valuesusing log
data['Capital_gain']=np.log(data['Capital_gain'])

# %%
data['Capital_loss']=np.log(data['Capital_loss'])

# %%
#lets check zeros 
#lets check
count=(data==0).sum()
count
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %%
#data visualization
# for that importing necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ax=sns.countplot(x='Age',data=data)
print(data['Age'].value_counts())
# Out:
# 36    898
# 31    888
# 34    886
# 23    877
# 35    876
#      ...
# 83      6
# 88      3
# 85      3
# 86      1
# 87      1
# Name: Age, Length: 73, dtype: int64

# %%
ax=sns.countplot(x='Workclass',data=data)
print(data['Workclass'].value_counts())
# Out:
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1297
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: Workclass, dtype: int64

# %%
# from the above observation i can say that most of the private employed have good income and very less are there who are working without pay 
# and very very les have never worked

# %%
ax=sns.countplot(x='Education',data=data)
print(data['Education'].value_counts())
# Out:
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5354
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           333
#  1st-4th           168
#  Preschool          51
# Name: Education, dtype: int64

# %%
#according to me  from the above observation that an individual with hs -grad have the higher probability to earn good income

# %%
ax=sns.countplot(x='Education_num',data=data)
print(data['Education_num'].value_counts())
# Out:
# 9     10501
# 10     7291
# 13     5354
# 14     1723
# 11     1382
# 7      1175
# 12     1067
# 6       933
# 4       646
# 15      576
# 5       514
# 8       433
# 16      413
# 3       333
# 2       168
# 1        51
# Name: Education_num, dtype: int64

# %%
ax=sns.countplot(x='Marital_status',data=data)
print(data['Marital_status'].value_counts())
# Out:
#  Married-civ-spouse       14976
#  Never-married            10682
#  Divorced                  4443
#  Separated                 1025
#  Widowed                    993
#  Married-spouse-absent      418
#  Married-AF-spouse           23
# Name: Marital_status, dtype: int64

# %%
# from the above observation i can say that married civilian spouse and the individuals who have never married have good chances of earning good income
# and there is very less chance of married armed forces to earn 50k also whose spouse is absent have less chances

# %%
ax=sns.countplot(x='Occupation',data=data)
print(data['Occupation'].value_counts())
# Out:
#  Prof-specialty       4140
#  Craft-repair         4099
#  Exec-managerial      4066
#  Adm-clerical         3769
#  Sales                3650
#  Other-service        3295
#  Machine-op-inspct    2002
#  ?                    1843
#  Transport-moving     1597
#  Handlers-cleaners    1370
#  Farming-fishing       994
#  Tech-support          928
#  Protective-serv       649
#  Priv-house-serv       149
#  Armed-Forces            9
# Name: Occupation, dtype: int64

# %%
ax=sns.countplot(x='Relationship',data=data)
print(data['Relationship'].value_counts())
# Out:
#  Husband           13193
#  Not-in-family      8304
#  Own-child          5068
#  Unmarried          3446
#  Wife               1568
#  Other-relative      981
# Name: Relationship, dtype: int64

# %%
# according to me husbands are predicted to have good income in comparision to others

# %%
ax=sns.countplot(x='Race',data=data)
print(data['Race'].value_counts())
# Out:
#  White                 27815
#  Black                  3124
#  Asian-Pac-Islander     1039
#  Amer-Indian-Eskimo      311
#  Other                   271
# Name: Race, dtype: int64

# %%
# whites have higher probability to eaarn income more than 50k

# %%
ax=sns.countplot(x='Sex',data=data)
print(data['Sex'].value_counts())
# Out:
#  Male      21789
#  Female    10771
# Name: Sex, dtype: int64

# %%
# males have higher probability than females

# %%
print(data['Native_country'].value_counts())
# Out:
#  United-States                 29169
#  Mexico                          643
#  ?                               583
#  Philippines                     198
#  Germany                         137
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Guatemala                        64
#  Japan                            62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
# ...

# %%
# individuals who have united states as their native country have higher probability to earn more than 50k
# on the contrary holand and netherland have lower probability

# %%
ax=sns.countplot(x='Income',data=data)
print(data['Income'].value_counts())
# Out:
#  <=50K    24719
#  >50K      7841
# Name: Income, dtype: int64

# %%
# lets check the skewness

# %%
data.skew()
# Out:
# Age               0.558738
# Fnlwgt            1.446972
# Education_num    -0.311630
# Capital_gain           NaN
# Capital_loss           NaN
# Hours_per_week    0.227636
# dtype: float64

# %%
# most of the columns are of object datatype lets encode them
from sklearn.preprocessing import LabelEncoder

# %%
data.dtypes
# Out:
# Age                 int64
# Workclass          object
# Fnlwgt              int64
# Education          object
# Education_num       int64
# Marital_status     object
# Occupation         object
# Relationship       object
# Race               object
# Sex                object
# Capital_gain      float64
# Capital_loss      float64
# Hours_per_week      int64
# Native_country     object
# Income             object
# dtype: object

# %%
lab_enc=LabelEncoder()

# %%
data2=lab_enc.fit_transform(data['Workclass'])
data['Workclass']=data2
data.head()
# Out:
#    Age  Workclass  Fnlwgt   Education  Education_num       Marital_status  \
# 0   50          6   83311   Bachelors             13   Married-civ-spouse
# 1   38          4  215646     HS-grad              9             Divorced
# 2   53          4  234721        11th              7   Married-civ-spouse
# 3   28          4  338409   Bachelors             13   Married-civ-spouse
# 4   37          4  284582     Masters             14   Married-civ-spouse
#
#            Occupation    Relationship    Race      Sex  Capital_gain  \
# 0     Exec-managerial         Husband   White     Male          -inf
# 1   Handlers-cleaners   Not-in-family   White     Male          -inf
# 2   Handlers-cleaners         Husband   Black     Male          -inf
# 3      Prof-specialty            Wife   Black   Female          -inf
# 4     Exec-managerial            Wife   White   Female          -inf
#
#    Capital_loss  Hours_per_week  Native_country  Income
# ...

# %%
data2=lab_enc.fit_transform(data['Education'])
data['Education']=data2
data.head()
# Out:
#    Age  Workclass  Fnlwgt  Education  Education_num       Marital_status  \
# 0   50          6   83311          9             13   Married-civ-spouse
# 1   38          4  215646         11              9             Divorced
# 2   53          4  234721          1              7   Married-civ-spouse
# 3   28          4  338409          9             13   Married-civ-spouse
# 4   37          4  284582         12             14   Married-civ-spouse
#
#            Occupation    Relationship    Race      Sex  Capital_gain  \
# 0     Exec-managerial         Husband   White     Male          -inf
# 1   Handlers-cleaners   Not-in-family   White     Male          -inf
# 2   Handlers-cleaners         Husband   Black     Male          -inf
# 3      Prof-specialty            Wife   Black   Female          -inf
# 4     Exec-managerial            Wife   White   Female          -inf
#
#    Capital_loss  Hours_per_week  Native_country  Income
# ...

# %%
data2=lab_enc.fit_transform(data['Marital_status'])
data['Marital_status']=data2
data.head()
# Out:
#    Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0   50          6   83311          9             13               2
# 1   38          4  215646         11              9               0
# 2   53          4  234721          1              7               2
# 3   28          4  338409          9             13               2
# 4   37          4  284582         12             14               2
#
#            Occupation    Relationship    Race      Sex  Capital_gain  \
# 0     Exec-managerial         Husband   White     Male          -inf
# 1   Handlers-cleaners   Not-in-family   White     Male          -inf
# 2   Handlers-cleaners         Husband   Black     Male          -inf
# 3      Prof-specialty            Wife   Black   Female          -inf
# 4     Exec-managerial            Wife   White   Female          -inf
#
#    Capital_loss  Hours_per_week  Native_country  Income
# 0          -inf              13   United-States   <=50K
# ...

# %%
data2=lab_enc.fit_transform(data['Occupation'])
data['Occupation']=data2
data.head()
# Out:
#    Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0   50          6   83311          9             13               2
# 1   38          4  215646         11              9               0
# 2   53          4  234721          1              7               2
# 3   28          4  338409          9             13               2
# 4   37          4  284582         12             14               2
#
#    Occupation    Relationship    Race      Sex  Capital_gain  Capital_loss  \
# 0           4         Husband   White     Male          -inf          -inf
# 1           6   Not-in-family   White     Male          -inf          -inf
# 2           6         Husband   Black     Male          -inf          -inf
# 3          10            Wife   Black   Female          -inf          -inf
# 4           4            Wife   White   Female          -inf          -inf
#
#    Hours_per_week  Native_country  Income
# 0              13   United-States   <=50K
# ...

# %%
data2=lab_enc.fit_transform(data['Relationship'])
data['Relationship']=data2
data.head()
# Out:
#    Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0   50          6   83311          9             13               2
# 1   38          4  215646         11              9               0
# 2   53          4  234721          1              7               2
# 3   28          4  338409          9             13               2
# 4   37          4  284582         12             14               2
#
#    Occupation  Relationship    Race      Sex  Capital_gain  Capital_loss  \
# 0           4             0   White     Male          -inf          -inf
# 1           6             1   White     Male          -inf          -inf
# 2           6             0   Black     Male          -inf          -inf
# 3          10             5   Black   Female          -inf          -inf
# 4           4             5   White   Female          -inf          -inf
#
#    Hours_per_week  Native_country  Income
# 0              13   United-States   <=50K
# ...

# %%
data2=lab_enc.fit_transform(data['Race'])
data['Race']=data2
data.head()
# Out:
#    Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0   50          6   83311          9             13               2
# 1   38          4  215646         11              9               0
# 2   53          4  234721          1              7               2
# 3   28          4  338409          9             13               2
# 4   37          4  284582         12             14               2
#
#    Occupation  Relationship  Race      Sex  Capital_gain  Capital_loss  \
# 0           4             0     4     Male          -inf          -inf
# 1           6             1     4     Male          -inf          -inf
# 2           6             0     2     Male          -inf          -inf
# 3          10             5     2   Female          -inf          -inf
# 4           4             5     4   Female          -inf          -inf
#
#    Hours_per_week  Native_country  Income
# 0              13   United-States   <=50K
# 1              40   United-States   <=50K
# ...

# %%
data2=lab_enc.fit_transform(data['Sex'])
data['Sex']=data2
data.head()
# Out:
#    Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0   50          6   83311          9             13               2
# 1   38          4  215646         11              9               0
# 2   53          4  234721          1              7               2
# 3   28          4  338409          9             13               2
# 4   37          4  284582         12             14               2
#
#    Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# 0           4             0     4    1          -inf          -inf
# 1           6             1     4    1          -inf          -inf
# 2           6             0     2    1          -inf          -inf
# 3          10             5     2    0          -inf          -inf
# 4           4             5     4    0          -inf          -inf
#
#    Hours_per_week  Native_country  Income
# 0              13   United-States   <=50K
# 1              40   United-States   <=50K
# ...

# %%
data2=lab_enc.fit_transform(data['Native_country'])
data['Native_country']=data2
data.head()
# Out:
#    Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0   50          6   83311          9             13               2
# 1   38          4  215646         11              9               0
# 2   53          4  234721          1              7               2
# 3   28          4  338409          9             13               2
# 4   37          4  284582         12             14               2
#
#    Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# 0           4             0     4    1          -inf          -inf
# 1           6             1     4    1          -inf          -inf
# 2           6             0     2    1          -inf          -inf
# 3          10             5     2    0          -inf          -inf
# 4           4             5     4    0          -inf          -inf
#
#    Hours_per_week  Native_country  Income
# 0              13              39   <=50K
# 1              40              39   <=50K
# ...

# %%
data2=lab_enc.fit_transform(data['Income'])
data['Income']=data2
data.head()
# Out:
#    Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0   50          6   83311          9             13               2
# 1   38          4  215646         11              9               0
# 2   53          4  234721          1              7               2
# 3   28          4  338409          9             13               2
# 4   37          4  284582         12             14               2
#
#    Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# 0           4             0     4    1          -inf          -inf
# 1           6             1     4    1          -inf          -inf
# 2           6             0     2    1          -inf          -inf
# 3          10             5     2    0          -inf          -inf
# 4           4             5     4    0          -inf          -inf
#
#    Hours_per_week  Native_country  Income
# 0              13              39       0
# 1              40              39       0
# ...

# %%
data.tail(10)
# Out:
#        Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 32550   32          4   34066          0              6               2
# 32551   43          4   84661          8             11               2
# 32552   32          4  116138         12             14               4
# 32553   53          4  321865         12             14               2
# 32554   22          4  310152         15             10               4
# 32555   27          4  257302          7             12               2
# 32556   40          4  154374         11              9               2
# 32557   58          4  151910         11              9               6
# 32558   22          4  201490         11              9               4
# 32559   52          5  287927         11              9               2
#
#        Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# 32550           6             0     0    1          -inf          -inf
# ...

# %%
data.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %%
data['Capital_gain']=data['Capital_gain'].fillna(data['Capital_gain'].mean())

# %%
data.skew()
# Out:
# Age               0.558738
# Workclass        -0.752280
# Fnlwgt            1.446972
# Education        -0.934063
# Education_num    -0.311630
# Marital_status   -0.013448
# Occupation        0.114540
# Relationship      0.786784
# Race             -2.435332
# Sex              -0.719244
# Capital_gain           NaN
# Capital_loss           NaN
# Hours_per_week    0.227636
# Native_country   -3.658235
# Income            1.212383
# dtype: float64

# %%
data.dtypes
# Out:
# Age                 int64
# Workclass           int32
# Fnlwgt              int64
# Education           int32
# Education_num       int64
# Marital_status      int32
# Occupation          int32
# Relationship        int32
# Race                int32
# Sex                 int32
# Capital_gain      float64
# Capital_loss      float64
# Hours_per_week      int64
# Native_country      int32
# Income              int32
# dtype: object

# %%
data['Capital_loss'].head(10)
# Out:
# 0   -inf
# 1   -inf
# 2   -inf
# 3   -inf
# 4   -inf
# 5   -inf
# 6   -inf
# 7   -inf
# 8   -inf
# 9   -inf
# Name: Capital_loss, dtype: float64

# %%
data['Capital_loss']=np.log(data['Capital_loss'])

# %%
data['Capital_loss'].head(10)
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# 6   NaN
# 7   NaN
# 8   NaN
# 9   NaN
# Name: Capital_loss, dtype: float64

# %%
data.isnull().sum()
# Out:
# Age                   0
# Workclass             0
# Fnlwgt                0
# Education             0
# Education_num         0
# Marital_status        0
# Occupation            0
# Relationship          0
# Race                  0
# Sex                   0
# Capital_gain          0
# Capital_loss      31041
# Hours_per_week        0
# Native_country        0
# Income                0
# dtype: int64

# %%
data['Capital_loss']=data['Capital_loss'].fillna(data['Capital_loss'].mean())

# %%
data.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %%
plt.figure(figsize=(20,25),facecolor='yellow')
plotnumber=1
for column in data:
    if plotnumber<=15:
        ax=plt.subplot(5,3,plotnumber)
        sns.boxplot(data[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %%
# lets check the correlation
# plotting the heatmaap
corr=data.corr()
corr
# Out:
#                      Age  Workclass    Fnlwgt  Education  Education_num  \
# Age             1.000000   0.003786 -0.076646  -0.010508       0.036527
# Workclass       0.003786   1.000000 -0.016587   0.023537       0.052015
# Fnlwgt         -0.076646  -0.016587  1.000000  -0.028156      -0.043159
# Education      -0.010508   0.023537 -0.028156   1.000000       0.359172
# Education_num   0.036527   0.052015 -0.043159   0.359172       1.000000
# Marital_status -0.266292  -0.064798  0.028184  -0.038398      -0.069338
# Occupation     -0.020946   0.255004  0.001554  -0.021274       0.109748
# Relationship   -0.263698  -0.090449  0.008922  -0.010879      -0.094145
# Race            0.028718   0.049720 -0.021278   0.014135       0.031825
# Sex             0.088832   0.095942  0.026882  -0.027349       0.012256
# Capital_gain    0.147569   0.126939  0.011419   0.131105       0.407610
# Capital_loss    0.024372   0.013162 -0.003528   0.005729       0.021738
# ...

# %%
plt.figure(figsize=(12,10))
sns.heatmap(corr,annot=True)
plt.show()

# %%
# no features are correlated
# lets check the skewness
data.skew()
# Out:
# Age                0.558738
# Workclass         -0.752280
# Fnlwgt             1.446972
# Education         -0.934063
# Education_num     -0.311630
# Marital_status    -0.013448
# Occupation         0.114540
# Relationship       0.786784
# Race              -2.435332
# Sex               -0.719244
# Capital_gain            NaN
# Capital_loss     -21.085295
# Hours_per_week     0.227636
# Native_country    -3.658235
# Income             1.212383
# dtype: float64

# %%
data.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %%
data.head()
# Out:
#    Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0   50          6   83311          9             13               2
# 1   38          4  215646         11              9               0
# 2   53          4  234721          1              7               2
# 3   28          4  338409          9             13               2
# 4   37          4  284582         12             14               2
#
#    Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# 0           4             0     4    1          -inf      2.015389
# 1           6             1     4    1          -inf      2.015389
# 2           6             0     2    1          -inf      2.015389
# 3          10             5     2    0          -inf      2.015389
# 4           4             5     4    0          -inf      2.015389
#
#    Hours_per_week  Native_country  Income
# 0              13              39       0
# 1              40              39       0
# ...

# %%
data['Capital_loss']=np.log(data['Capital_loss'])

# %%
data['Capital_loss'].head(10)
# Out:
# 0    0.700812
# 1    0.700812
# 2    0.700812
# 3    0.700812
# 4    0.700812
# 5    0.700812
# 6    0.700812
# 7    0.700812
# 8    0.700812
# 9    0.700812
# Name: Capital_loss, dtype: float64

# %%
data.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %%
data.head()
# Out:
#    Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0   50          6   83311          9             13               2
# 1   38          4  215646         11              9               0
# 2   53          4  234721          1              7               2
# 3   28          4  338409          9             13               2
# 4   37          4  284582         12             14               2
#
#    Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# 0           4             0     4    1          -inf      0.700812
# 1           6             1     4    1          -inf      0.700812
# 2           6             0     2    1          -inf      0.700812
# 3          10             5     2    0          -inf      0.700812
# 4           4             5     4    0          -inf      0.700812
#
#    Hours_per_week  Native_country  Income
# 0              13              39       0
# 1              40              39       0
# ...

# %%
data['Capital_gain']=np.log(data['Capital_gain'])

# %%
data.head()
# Out:
#    Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0   50          6   83311          9             13               2
# 1   38          4  215646         11              9               0
# 2   53          4  234721          1              7               2
# 3   28          4  338409          9             13               2
# 4   37          4  284582         12             14               2
#
#    Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# 0           4             0     4    1           NaN      0.700812
# 1           6             1     4    1           NaN      0.700812
# 2           6             0     2    1           NaN      0.700812
# 3          10             5     2    0           NaN      0.700812
# 4           4             5     4    0           NaN      0.700812
#
#    Hours_per_week  Native_country  Income
# 0              13              39       0
# 1              40              39       0
# ...

# %%
data.isnull().sum()
# Out:
# Age                   0
# Workclass             0
# Fnlwgt                0
# Education             0
# Education_num         0
# Marital_status        0
# Occupation            0
# Relationship          0
# Race                  0
# Sex                   0
# Capital_gain      29849
# Capital_loss          0
# Hours_per_week        0
# Native_country        0
# Income                0
# dtype: int64

# %%
data['Capital_gain']=data['Capital_gain'].fillna(data['Capital_gain'].mean())

# %%
data.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %%
data.skew()
# Out:
# Age                0.558738
# Workclass         -0.752280
# Fnlwgt             1.446972
# Education         -0.934063
# Education_num     -0.311630
# Marital_status    -0.013448
# Occupation         0.114540
# Relationship       0.786784
# Race              -2.435332
# Sex               -0.719244
# Capital_gain      -0.293729
# Capital_loss     -23.483301
# Hours_per_week     0.227636
# Native_country    -3.658235
# Income             1.212383
# dtype: float64

# %%
# lets use power transformer to reduce the skewness
from sklearn.preprocessing import PowerTransformer
scaler=PowerTransformer(method='yeo-johnson')

# %%
features=['Age','Workclass','Fnlwgt','Education','Relationship','Race','Sex','Capital_loss','Native_country']

# %%
data[features]=scaler.fit_transform(data[features].values)

# %%
data[features]
# Out:
#             Age  Workclass    Fnlwgt  Education  Relationship      Race  \
# 0      0.891947   1.644223 -1.089889  -0.477012     -1.094635  0.412893
# 1      0.102717   0.011864  0.398743   0.090482      0.134511  0.412893
# 2      1.064381   0.011864  0.562540  -2.067600     -1.094635 -2.431920
# 3     -0.731663   0.011864  1.340398  -0.477012      1.549018 -2.431920
# 4      0.028023   0.011864  0.957182   0.395133      1.549018  0.412893
# ...         ...        ...       ...        ...           ...       ...
# 32555 -0.827983   0.011864  0.746749  -0.984718      1.549018  0.412893
# 32556  0.247374   0.011864 -0.193298   0.090482     -1.094635  0.412893
# 32557  1.334556   0.011864 -0.219755   0.090482      1.351388  0.412893
# 32558 -1.358341   0.011864  0.271668   0.090482      1.091081  0.412893
# 32559  1.007823   0.794301  0.982165   0.090482      1.549018  0.412893
#
#             Sex  Capital_loss  Native_country
# 0      0.703087     -0.033407        0.329074
# ...

# %%
plt.figure(figsize=(20,25),facecolor='yellow')
plotnumber=1
for column in data[features]:
    if plotnumber<=15:
        ax=plt.subplot(5,3,plotnumber)
        sns.distplot(data[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %%
data.skew()
# Out:
# Age              -0.013897
# Workclass         0.061629
# Fnlwgt            0.016914
# Education        -0.309431
# Education_num    -0.311630
# Marital_status   -0.013448
# Occupation        0.114540
# Relationship      0.122917
# Race             -2.010817
# Sex              -0.719244
# Capital_gain     -0.293729
# Capital_loss      4.030033
# Hours_per_week    0.227636
# Native_country   -2.725467
# Income            1.212383
# dtype: float64

# %%
data.skew()
# Out:
# Age              -0.013897
# Workclass         0.061629
# Fnlwgt            0.016914
# Education        -0.309431
# Education_num    -0.311630
# Marital_status   -0.013448
# Occupation        0.114540
# Relationship      0.122917
# Race             -2.010817
# Sex              -0.719244
# Capital_gain     -0.293729
# Capital_loss      4.030033
# Hours_per_week    0.227636
# Native_country   -2.725467
# Income            1.212383
# dtype: float64

# %%
# splitting the datasetinto features and target
#now that we have dealt with skewness to great extent

x=data.drop(columns=['Income'])
y=data['Income']

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix,roc_auc_score
from sklearn.linear_model import LinearRegression

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=355)

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_reg=LogisticRegression()

# %%
log_reg.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=log_reg.predict(x_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 1, 0])

# %%
#model accuracy
accuracy=accuracy_score(y_test,y_pred)
accuracy
# Out:
# 0.8061425061425062

# %%
# lets try with another model
from sklearn.tree import DecisionTreeClassifier

# %%
def metric_score(clf,x_train,x_test,y_train,y_test,train=True):
    if train:
        y_pred=clf.predict(x_train)
        print("\n =======training  result==============")
        print(f"accuracy score:{accuracy_score(y_train,y_pred)*100:.2f}%")
    elif train==False:
        pred=clf.predict(x_test)
        print("\n =======testing  result==============")
        print(f"accuracy score:{accuracy_score(y_test,pred)*100:.2f}%")

# %%
clf=DecisionTreeClassifier()
clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
#==========training score====================
metric_score(clf,x_train,x_test,y_train,y_test,train=True)
#================testing score===============
metric_score(clf,x_train,x_test,y_train,y_test,train=False)
# Out:
#  =======training  result==============
# accuracy score:100.00%
#
#  =======testing  result==============
# accuracy score:80.55%

# %%
# hyper parameter tuning
from sklearn.model_selection import GridSearchCV

# %%
grid_param={'criterion':['gini','entropy'],
            'max_depth':range(10,15),
            'min_samples_leaf':range(2,6),
            'min_samples_split':range(3,8),
            'max_leaf_nodes':(5,10)}
grid_search=GridSearchCV(estimator=clf,param_grid=grid_param)
grid_search.fit(x_train,y_train)
best_parameters=grid_search.best_params_
print(best_parameters)
# Out:
# {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_leaf': 2, 'min_samples_split': 3}

# %%
# initialising and training model
clf=DecisionTreeClassifier(criterion='gini',max_depth=10,max_leaf_nodes=10,min_samples_leaf=2,min_samples_split=3)
clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=10, max_leaf_nodes=10, min_samples_leaf=2,
#                        min_samples_split=3)

# %%
#==========training score====================
metric_score(clf,x_train,x_test,y_train,y_test,train=True)
#================testing score===============
metric_score(clf,x_train,x_test,y_train,y_test,train=False)
# Out:
#  =======training  result==============
# accuracy score:84.42%
#
#  =======testing  result==============
# accuracy score:83.73%

# %%
# lets save the model
import pickle

# %%
pickle.dump(clf,open('income','wb'))

# %%
loaded_model=pickle.load(open('income','rb'))

# %%
result=loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# 83.73464373464373

# %%
#=======================thank you===========================
