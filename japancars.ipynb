# %%
# importing necessary libraries
import pandas as pd
import numpy as np

# %%
#loading the dataset
df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/dataset4/main/Japan_used_cars_datasets.csv")
df.head()
# Out:
#    id  price      mark    model  year  mileage  engine_capacity transmission  \
# 0   0     80    nissan    march  2003    80000             1240           at
# 1   1    110    nissan    march  2010    53000             1200           at
# 2   2    165    nissan  lafesta  2005    47690             2000           at
# 3   3    190    toyota  avensis  2008   130661             1990           at
# 4   4    190  daihatsu     mira  2006    66300              660           at
#
#   drive hand_drive      fuel
# 0   2wd        rhd  gasoline
# 1   2wd        rhd  gasoline
# 2   2wd        rhd  gasoline
# 3   2wd        rhd  gasoline
# 4   2wd        rhd  gasoline

# %%
# checking the shape 
df.shape
# Out:
# (2318, 11)

# %%
# checking for nulls
df.isnull().sum()
# Out:
# id                 0
# price              0
# mark               0
# model              0
# year               0
# mileage            0
# engine_capacity    0
# transmission       0
# drive              0
# hand_drive         0
# fuel               0
# dtype: int64

# %%
# there are no null values good lets move further

# %%
df.describe()
# Out:
#                 id        price         year        mileage  engine_capacity
# count  2318.000000  2318.000000  2318.000000    2318.000000      2318.000000
# mean   1169.047023   971.522433  2005.972390  100013.194996      1507.010785
# std     674.460724   288.673112     3.698863   52512.478883       549.585170
# min       0.000000    80.000000  1979.000000    2000.000000         9.000000
# 25%     583.250000   776.000000  2004.000000   67000.000000      1300.000000
# 50%    1168.500000  1000.000000  2006.000000   94000.000000      1490.000000
# 75%    1753.750000  1213.000000  2009.000000  124000.000000      1800.000000
# max    2335.000000  1400.000000  2015.000000  790000.000000     12340.000000

# %%
df.dtypes
# Out:
# id                  int64
# price               int64
# mark               object
# model              object
# year                int64
# mileage             int64
# engine_capacity     int64
# transmission       object
# drive              object
# hand_drive         object
# fuel               object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2318 entries, 0 to 2317
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               2318 non-null   int64
#  1   price            2318 non-null   int64
#  2   mark             2318 non-null   object
#  3   model            2318 non-null   object
#  4   year             2318 non-null   int64
#  5   mileage          2318 non-null   int64
#  6   engine_capacity  2318 non-null   int64
#  7   transmission     2318 non-null   object
#  8   drive            2318 non-null   object
#  9   hand_drive       2318 non-null   object
#  10  fuel             2318 non-null   object
# dtypes: int64(5), object(6)
# memory usage: 199.3+ KB

# %%
sum(df.duplicated(subset='id'))==0
# Out:
# True

# %%
# data visualization
#importing necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ax=sns.countplot(x='mark',data=df)
print(df['mark'].value_counts())
# Out:
# toyota           1047
# honda             382
# nissan            320
# mazda             148
# suzuki            126
# mitsubishi         65
# daihatsu           56
# subaru             54
# volkswagen         52
# bmw                27
# hyundai             9
# mercedes-benz       5
# kia motors          4
# isuzu               3
# audi                3
# smart               2
# volvo               2
# land rover          2
# peugeot             2
# hino                1
# mitsuoka            1
# ford                1
# gm                  1
# citroen             1
# opel                1
# chrysler            1
# kubota              1
# jaguar              1
# Name: mark, dtype: int64

# %%
# from the above observation we can say that most of the people prefer to buy toyota
# honda ,nisan,mazda and suzuki are also preferred by some people

# %%
print(df['year'].value_counts())
# Out:
# 2005    365
# 2007    318
# 2003    248
# 2006    199
# 2009    199
# 2004    194
# 2011    173
# 2010    153
# 2008     91
# 2002     82
# 2001     77
# 2013     52
# 2012     42
# 1999     32
# 2000     27
# 1998     13
# 1997     13
# 1996      6
# 1995      6
# 1993      5
# 1994      4
# 2014      4
# 1990      4
# 1991      3
# 1992      3
# 1979      1
# 1982      1
# 2015      1
# 1987      1
# 1988      1
# Name: year, dtype: int64

# %%
# the above observation shows that after the year 1997 people started buying cars
# in the year 2005 more people bought second hand cars

# %%
ax=sns.countplot(x='transmission',data=df)
print(df['transmission'].value_counts())
# Out:
# at     2171
# mt      117
# cvt      30
# Name: transmission, dtype: int64

# %%
# people prefer to buy automatic transmission in cars than the other two

# %%
ax=sns.countplot(x='drive',data=df)
print(df['drive'].value_counts())
# Out:
# 2wd    2121
# 4wd     192
# awd       5
# Name: drive, dtype: int64

# %%
# most of the people prefer 2wd vehicle as it works fine in rain and light snow 
# 2wd vehicleis powered by 2 wheels while four wheels rotate

# %%
ax=sns.countplot(x='hand_drive',data=df)
print(df['hand_drive'].value_counts())
# Out:
# rhd       2301
# lhd         16
# center       1
# Name: hand_drive, dtype: int64

# %%
# most people prefer to buy the cars having steering on right hand side

# %%
ax=sns.countplot(x='fuel',data=df)
print(df['fuel'].value_counts())
# Out:
# gasoline    2290
# diesel        18
# lpg            7
# hybrid         2
# cng            1
# Name: fuel, dtype: int64

# %%
#most of the people buy the cars which use gasoline or petrol as fuel in cars

# %%
# visualization of numeric columns

# %%
ax=sns.countplot(x='engine_capacity',data=df)
print(df['engine_capacity'].value_counts())
# Out:
# 1300    468
# 1500    433
# 2000    197
# 1000    168
# 660     159
#        ...
# 1986      1
# 798       1
# 1587      1
# 1270      1
# 1999      1
# Name: engine_capacity, Length: 93, dtype: int64

# %%
ax=sns.countplot(x='price',data=df)
print(df['price'].value_counts())
# Out:
# 850     71
# 790     58
# 1306    57
# 1120    56
# 1220    45
#         ..
# 1121     1
# 1122     1
# 1123     1
# 1127     1
# 80       1
# Name: price, Length: 354, dtype: int64

# %%
df.head()
# Out:
#    id  price      mark    model  year  mileage  engine_capacity transmission  \
# 0   0     80    nissan    march  2003    80000             1240           at
# 1   1    110    nissan    march  2010    53000             1200           at
# 2   2    165    nissan  lafesta  2005    47690             2000           at
# 3   3    190    toyota  avensis  2008   130661             1990           at
# 4   4    190  daihatsu     mira  2006    66300              660           at
#
#   drive hand_drive      fuel
# 0   2wd        rhd  gasoline
# 1   2wd        rhd  gasoline
# 2   2wd        rhd  gasoline
# 3   2wd        rhd  gasoline
# 4   2wd        rhd  gasoline

# %%
# it seems that id is not an important column lets delete it
df=df.drop('id',axis=1)

# %%
# visualise the outliers using boxplot
plt.figure(figsize=(15,20))
plotnumber=1
for column in df:
    if plotnumber<=10:
        plt.subplot(2,5,plotnumber)
        ax=sns.boxplot(data=df)
        plt.xlabel(column,fontsize=15)
    plotnumber+=1
plt.show()

# %%
# encoding of dataframe 
# importing libraries
from sklearn.preprocessing import OrdinalEncoder

# %%
enc=OrdinalEncoder()

# %%
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=enc.fit_transform(df[i].values.reshape(-1,1))
df
# Out:
#       price  mark  model  year  mileage  engine_capacity  transmission  drive  \
# 0        80  19.0  143.0  2003    80000             1240           0.0    0.0
# 1       110  19.0  143.0  2010    53000             1200           0.0    0.0
# 2       165  19.0  134.0  2005    47690             2000           0.0    0.0
# 3       190  25.0   29.0  2008   130661             1990           0.0    0.0
# 4       190   4.0  155.0  2006    66300              660           0.0    0.0
# ...     ...   ...    ...   ...      ...              ...           ...    ...
# 2313   1400  25.0  242.0  2009   121000              996           0.0    0.0
# 2314   1400  25.0  100.0  2003   101000             3000           0.0    0.0
# 2315   1400  23.0  195.0  2005   101000              660           1.0    0.0
# 2316   1400   8.0  256.0  2000   170000              660           0.0    1.0
# 2317   1400  25.0  101.0  2005    72320             3000           0.0    0.0
#
#       hand_drive  fuel
# ...

# %%
# checking the datatypes
df.dtypes
# Out:
# price                int64
# mark               float64
# model              float64
# year                 int64
# mileage              int64
# engine_capacity      int64
# transmission       float64
# drive              float64
# hand_drive         float64
# fuel               float64
# dtype: object

# %%
# checking the information of columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2318 entries, 0 to 2317
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   price            2318 non-null   int64
#  1   mark             2318 non-null   float64
#  2   model            2318 non-null   float64
#  3   year             2318 non-null   int64
#  4   mileage          2318 non-null   int64
#  5   engine_capacity  2318 non-null   int64
#  6   transmission     2318 non-null   float64
#  7   drive            2318 non-null   float64
#  8   hand_drive       2318 non-null   float64
#  9   fuel             2318 non-null   float64
# dtypes: float64(6), int64(4)
# memory usage: 181.2 KB

# %%
# checking the correlation 
df.corr()['price'].sort_values()
# Out:
# year              -0.211092
# model             -0.041376
# hand_drive        -0.036473
# fuel              -0.016337
# mileage            0.021581
# transmission       0.043679
# drive              0.046591
# mark               0.090245
# engine_capacity    0.173748
# price              1.000000
# Name: price, dtype: float64

# %%
# if the correlation value is greater than 0.5 then it is considered as greatest correlation with label
plt.figure(figsize=(22,7))
sns.heatmap(df.corr(),annot=True,linewidth=0.1,linecolor="black",fmt="0.2f")
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(22,7))
df.corr()['price'].sort_values(ascending=False).drop(['price']).plot(kind='bar',color='c')
plt.xlabel('feature',fontsize=14)
plt.ylabel('column with target name',fontsize=14)
plt.title("Correlation",fontsize=18)
plt.show()

# %%
# we observe that there is negative  correlation of model,year,hand_drive,andfuel with target variable

# %%
# we will delete the year column
df=df.drop("year",axis=1)

# %%
# lets check skewness
df.skew()
# Out:
# price              -0.466780
# mark               -0.947938
# model              -0.267060
# mileage             3.089142
# engine_capacity     4.038892
# transmission        3.820441
# drive               3.193137
# hand_drive        -12.811470
# fuel                4.146744
# dtype: float64

# %%
# keeping +/-0.5 as the range for skewness
# we will not delete the outliers from categorical as well as target variable
# check the outliers on integer and float data type (that were originally float before encoding)

# %%
# using z score 
# importing necessary library
from scipy.stats import zscore
import numpy as np

# %%
z=np.abs(zscore(df))
threshholds=3
np.where(z>3)
# Out:
# (array([   0,    7,    7,    8,   10,   23,   23,   23,   23,   52,   54,
#           75,   87,  103,  111,  111,  132,  134,  138,  145,  146,  160,
#          171,  171,  186,  196,  198,  243,  246,  247,  249,  253,  259,
#          268,  274,  293,  309,  312,  314,  334,  353,  359,  401,  401,
#          404,  406,  409,  414,  416,  432,  441,  444,  446,  456,  466,
#          467,  472,  485,  492,  495,  495,  502,  503,  507,  507,  508,
#          529,  533,  549,  551,  580,  594,  674,  675,  681,  691,  693,
#          696,  696,  700,  723,  724,  729,  732,  738,  739,  740,  741,
#          741,  742,  743,  749,  750,  751,  752,  753,  811,  818,  818,
#          820,  823,  829,  834,  841,  842,  854,  862,  869,  877,  879,
#          883,  891,  908,  913,  926,  927,  927,  938,  940,  941,  954,
#          956,  956,  958,  970,  971,  971,  973,  979, 1001, 1003, 1004,
#         1006, 1006, 1006, 1012, 1019, 1024, 1036, 1046, 1065, 1065, 1066,
# ...

# %%
# we are keeping only those columns whose zscore value is less than or equal to 3
df_new_z=df[(z<3).all(axis=1)]
df_new_z.shape
# Out:
# (2002, 9)

# %%
# data loss
data_loss=((2318-2002)/2318)*100
data_loss
# Out:
# 13.63244176013805

# %%
#seperating the columns into feature and target
x=df.drop('price',axis=1)
y=df["price"]

# %%
# scaling the data 
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import warnings
warnings.filterwarnings('ignore')

# %%
scaler=StandardScaler()
lr=LinearRegression()

# %%
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=i)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
print(f"at random state{i},the training accuracy is:",{r2_score(y_train,pred_train)})
print(f"at random state{i},the testing accuracy is:",{r2_score(y_test,pred_test)})
print("\n")
# Out:
# at random state99,the training accuracy is: {0.05095117561938767}
# at random state99,the testing accuracy is: {0.021828864725638497}

# %%
scaler=StandardScaler()
lr=LinearRegression()
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=i)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    print(f"at random state{i},the training accuracy is:,{r2_score(y_train,pred_train)}")
    print(f"at random state{i},the testing accuracy is:,{r2_score(y_test,pred_test)}")
    print("\n")
# Out:
# at random state0,the training accuracy is:,0.04617514703569525
# at random state0,the testing accuracy is:,0.030682910389216778
#
#
# at random state1,the training accuracy is:,0.048716088066405816
# at random state1,the testing accuracy is:,0.01945773404099449
#
#
# at random state2,the training accuracy is:,0.050001135173775024
# at random state2,the testing accuracy is:,0.021203636744635213
#
#
# at random state3,the training accuracy is:,0.05040461133372787
# at random state3,the testing accuracy is:,0.02448899604170318
#
#
# at random state4,the training accuracy is:,0.045229290304309555
# at random state4,the testing accuracy is:,0.034041431975375125
#
#
# at random state5,the training accuracy is:,0.04106122923245836
# at random state5,the testing accuracy is:,0.051872162442803904
#
#
# at random state6,the training accuracy is:,0.038699702003243686
# at random state6,the testing accuracy is:,0.05813946699442829
#
#
# ...

# %%
scaler=StandardScaler()
lr=LinearRegression()
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=i)
    lr.fit(x_train,y_train)

# %%
pred_test=lr.predict(x_test)
print(r2_score(y_test,pred_test))
# Out:
# 0.021828864725638497

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf=RandomForestRegressor()

# %%
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=i)
    rf.fit(x_train,y_train)
    pred_train=rf.predict(x_train)
    pred_test=rf.predict(x_test)
    print(f"at random state{i},the training accuracy is:",{r2_score(y_train,pred_train)})
    print(f"at random state{i},the testing accuracy is:",{r2_score(y_test,pred_test)})
    print("\n")
# Out:
# at random state0,the training accuracy is: {0.8772558444570142}
# at random state0,the testing accuracy is: {0.10147319333882077}
#
#
# at random state1,the training accuracy is: {0.8723880835431618}
# at random state1,the testing accuracy is: {0.09772211674105447}
#
#
# at random state2,the training accuracy is: {0.8720183649893143}
# at random state2,the testing accuracy is: {0.2305211858817806}
#
#
# at random state3,the training accuracy is: {0.8748635437903124}
# at random state3,the testing accuracy is: {0.1610798685331648}
#
#
# at random state4,the training accuracy is: {0.870986445069578}
# at random state4,the testing accuracy is: {0.19466003457059744}
#
#
# at random state5,the training accuracy is: {0.872074056125215}
# at random state5,the testing accuracy is: {0.11347401882876618}
#
#
# at random state6,the training accuracy is: {0.8708513864094545}
# at random state6,the testing accuracy is: {0.12109104656921854}
#
#
# ...

# %%
from sklearn.linear_model import LogisticRegression

# %%
logr=LogisticRegression()

# %%
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=i)
    logr.fit(x_train,y_train)
    pred_train=logr.predict(x_train)
    pred_test=logr.predict(x_test)
    print(f"at random state{i},the training accuracy is:,{r2_score(y_train,pred_train)}")
    print(f"at random state{i},the testing accuracy is:,{r2_score(y_test,pred_test)}")
    print("\n")
# Out:
# at random state0,the training accuracy is:,-0.42627442785565783
# at random state0,the testing accuracy is:,-0.5066295472667846
#
#
# at random state1,the training accuracy is:,-0.4270227430866085
# at random state1,the testing accuracy is:,-0.4391763685285881
#
#
# at random state2,the training accuracy is:,-0.26874324311416276
# at random state2,the testing accuracy is:,-0.23987850849435777
#
#
# at random state3,the training accuracy is:,-0.38022245896750473
# at random state3,the testing accuracy is:,-0.5343594373441014
#
#
# at random state4,the training accuracy is:,-0.47150715684694133
# at random state4,the testing accuracy is:,-0.2748390766313751
#
#
# at random state5,the training accuracy is:,-0.42282289703880527
# at random state5,the testing accuracy is:,-0.4092353124528316
#
#
# at random state6,the training accuracy is:,-0.29343142839278147
# at random state6,the testing accuracy is:,-0.3504863265217599
#
#
# ...

# %%
# cross validation
train_accuracy=r2_score(y_train,pred_train)
test_accuracy=r2_score(y_test,pred_test)
from sklearn.model_selection import cross_val_score
for i in range(2,10):
    cv_score=cross_val_score(lr,x,y,cv=i)
    cv_mean=cv_score.mean()
    print(f"at cross fold{i}the cv score for training is{train_accuracy}and for test accuracy is{test_accuracy}")
    print("\n")
# Out:
# at cross fold2the cv score for training is-0.1805554492153758and for test accuracy is-0.14264282707310527
#
#
# at cross fold3the cv score for training is-0.1805554492153758and for test accuracy is-0.14264282707310527
#
#
# at cross fold4the cv score for training is-0.1805554492153758and for test accuracy is-0.14264282707310527
#
#
# at cross fold5the cv score for training is-0.1805554492153758and for test accuracy is-0.14264282707310527
#
#
# at cross fold6the cv score for training is-0.1805554492153758and for test accuracy is-0.14264282707310527
#
#
# at cross fold7the cv score for training is-0.1805554492153758and for test accuracy is-0.14264282707310527
#
#
# at cross fold8the cv score for training is-0.1805554492153758and for test accuracy is-0.14264282707310527
#
#
# at cross fold9the cv score for training is-0.1805554492153758and for test accuracy is-0.14264282707310527

# %%
# regularization
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.linear_model import Lasso

# %%
parameters={'alpha':[.001,.001,.01,.1,1],'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 1, 'random_state': 0}

# %%
ls=Lasso(alpha=.001,random_state=5)
ls.fit(x_train,y_train)
ls_score_training=ls.score(x_train,y_train)
pred_ls=ls.predict(x_test)
ls_score_training*100
# Out:
# 5.095117198122335

# %%
pred_ls=ls.predict(x_test)

# %%
lss=r2_score(y_test,pred_ls)
lss
# Out:
# 0.021831041595868905

# %%
parameters={'criterion':['mse','mae'],
           'max_features':["auto","sqrt","log2"]}
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'criterion': 'mae', 'max_features': 'sqrt'}

# %%
rf=RandomForestRegressor(criterion='mae',max_features='sqrt')
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
pred_decision=rf.predict(x_test)
rfs=r2_score(y_test,pred_decision)
print("r2 score",rfs*100)
rf_score=cross_val_score(rf,x,y,cv=5)
rfc=rf_score.mean()
print('crossvalscore:',rfc*100)
# Out:
# r2 score 17.730387805806135
# crossvalscore: -3338.4929250525756

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knr=KNeighborsRegressor()

# %%
parameters={'algorithm':['kd_tree','brute'],
           'leaf_size':[3,5,6,7,8],
           'n_neighbors':[3,5,7,9,11,13]}
knr=KNeighborsRegressor()
clf=GridSearchCV(knr,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'algorithm': 'brute', 'leaf_size': 3, 'n_neighbors': 13}

# %%
knr=KNeighborsRegressor(algorithm='brute',leaf_size=3,n_neighbors=13)
knr.fit(x_train,y_train)
knr.score(x_train,y_train)
pred_decision=knr.predict(x_test)
rfs=r2_score(y_test,pred_decision)
print("r2 score",rfs*100)
rf_score=cross_val_score(rf,x,y,cv=5)
rfc=rf_score.mean()
print('crossvalscore:',rfc*100)
# Out:
# r2 score -9.949967710438013
# crossvalscore: -3302.526974710942

# %%
# tried many models but no result is coming
