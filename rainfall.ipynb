# %%
import pandas as pd
import numpy as np

# %%
# loading the dataset
df=pd.read_csv("D:\dataset3-main\weatherAUS.csv")
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df.shape
# Out:
# (8425, 23)

# %%
# checking for nulls 
df.isnull().sum()
# Out:
# Date                0
# Location            0
# MinTemp            75
# MaxTemp            60
# Rainfall          240
# Evaporation      3512
# Sunshine         3994
# WindGustDir       991
# WindGustSpeed     991
# WindDir9am        829
# WindDir3pm        308
# WindSpeed9am       76
# WindSpeed3pm      107
# Humidity9am        59
# Humidity3pm       102
# Pressure9am      1309
# Pressure3pm      1312
# Cloud9am         2421
# Cloud3pm         2455
# Temp9am            56
# Temp3pm            96
# RainToday         240
# RainTomorrow      239
# dtype: int64

# %%
df.dtypes
# Out:
# Date              object
# Location          object
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am      float64
# Humidity3pm      float64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RainTomorrow      object
# dtype: object

# %%
# lets check for zeros
count=(df==0).sum()
count
# Out:
# Date                0
# Location            0
# MinTemp             4
# MaxTemp             0
# Rainfall         5299
# Evaporation        12
# Sunshine          166
# WindGustDir         0
# WindGustSpeed       0
# WindDir9am          0
# WindDir3pm          0
# WindSpeed9am      752
# WindSpeed3pm      199
# Humidity9am         0
# Humidity3pm         0
# Pressure9am         0
# Pressure3pm         0
# Cloud9am          554
# Cloud3pm          347
# Temp9am             0
# Temp3pm             0
# RainToday           0
# RainTomorrow        0
# dtype: int64

# %%
# lets treat null values
df['MinTemp']=df['MinTemp'].fillna(df['MinTemp'].mean())

# %%
df['RainTomorrow'].value_counts()
# Out:
# No     6195
# Yes    1991
# Name: RainTomorrow, dtype: int64

# %%
df['RainTomorrow']=df['RainTomorrow'].fillna('No')

# %%
df['WindDir3pm'].value_counts()
# Out:
# SE     813
# S      742
# SSE    623
# WSW    580
# NE     544
# N      524
# SW     494
# WNW    487
# NW     468
# W      462
# ESE    462
# E      460
# ENE    417
# SSW    370
# NNE    365
# NNW    306
# Name: WindDir3pm, dtype: int64

# %%
df['WindDir3pm']=df['WindDir3pm'].fillna('SE')

# %%
df['WindDir9am'].value_counts()
# Out:
# N      906
# SW     704
# NW     625
# WSW    543
# SE     505
# WNW    480
# SSW    467
# ENE    433
# NNE    430
# W      414
# NE     409
# S      402
# E      380
# SSE    365
# NNW    280
# ESE    253
# Name: WindDir9am, dtype: int64

# %%
df['WindDir9am']=df['WindDir9am'].fillna('N')

# %%
df['WindGustDir'].value_counts()
# Out:
# N      713
# SSE    578
# S      577
# SW     572
# E      557
# WNW    531
# W      507
# WSW    504
# SE     484
# ENE    415
# SSW    396
# NW     383
# NE     353
# NNE    343
# ESE    302
# NNW    219
# Name: WindGustDir, dtype: int64

# %%
df['WindGustDir']=df['WindGustDir'].fillna('N')

# %%
df['MaxTemp']=df['MaxTemp'].fillna(df['MaxTemp'].mean())
df['Rainfall']=df['Rainfall'].fillna(df['Rainfall'].mean())
df['Evaporation']=df['Evaporation'].fillna(df['Evaporation'].mean())
df['Sunshine']=df['Sunshine'].fillna(df['Sunshine'].mean())

# %%
df['WindGustDir']=df['WindGustDir'].fillna(df['WindGustDir'].mode())
df['WindGustSpeed']=df['WindGustSpeed'].fillna(df['WindGustSpeed'].mean())

# %%
df['WindDir9am']=df['WindDir9am'].fillna(df['WindDir9am'].mode())
df['WindDir3pm']=df['WindDir3pm'].fillna(df['WindDir3pm'].mode())
df['WindSpeed9am']=df['WindSpeed9am'].fillna(df['WindSpeed9am'].mean())
df['WindSpeed3pm']=df['WindSpeed3pm'].fillna(df['WindSpeed3pm'].mean())
df['Humidity9am']=df['Humidity9am'].fillna(df['Humidity9am'].mean())
df['Humidity3pm']=df['Humidity3pm'].fillna(df['Humidity3pm'].mean())
df['Pressure9am']=df['Pressure9am'].fillna(df['Pressure9am'].mean())
df['Pressure3pm']=df['Pressure3pm'].fillna(df['Pressure3pm'].mean())
df['Cloud9am']=df['Cloud9am'].fillna(df['Cloud9am'].mean())
df['Cloud3pm']=df['Cloud3pm'].fillna(df['Cloud3pm'].mean())
df['Temp9am']=df['Temp9am'].fillna(df['Temp9am'].mean())
df['Temp3pm']=df['Temp3pm'].fillna(df['Temp3pm'].mean())

# %%
df['RainToday']=df['RainToday'].fillna('No')
df['RainTomorrow']=df['RainTomorrow'].fillna(df['RainTomorrow'].mode())

# %%
#lets now check for nulls 
df.isnull().sum()
# Out:
# Date             0
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RainTomorrow     0
# dtype: int64

# %%
# lets check for zeros
count=(df==0).sum()
count
# Out:
# Date                0
# Location            0
# MinTemp             4
# MaxTemp             0
# Rainfall         5299
# Evaporation        12
# Sunshine          166
# WindGustDir         0
# WindGustSpeed       0
# WindDir9am          0
# WindDir3pm          0
# WindSpeed9am      752
# WindSpeed3pm      199
# Humidity9am         0
# Humidity3pm         0
# Pressure9am         0
# Pressure3pm         0
# Cloud9am          554
# Cloud3pm          347
# Temp9am             0
# Temp3pm             0
# RainToday           0
# RainTomorrow        0
# dtype: int64

# %%
# now lets treat zero
df['Cloud3pm']=df['Cloud3pm'].replace(0,df['Cloud3pm'].mean())
df['Cloud9am']=df['Cloud9am'].replace(0,df['Cloud9am'].mean())

# %%
df['WindSpeed3pm']=df['WindSpeed3pm'].replace(0,df['WindSpeed3pm'].mean())
df['WindSpeed9am']=df['WindSpeed9am'].replace(0,df['WindSpeed9am'].mean())
df['Sunshine']=df['Sunshine'].replace(0,df['Sunshine'].mean())
df['Evaporation']=df['Evaporation'].replace(0,df['Evaporation'].mean())
df['Rainfall']=df['Rainfall'].replace(0,df['Rainfall'].mean())

# %%
df['MinTemp']=df['MinTemp'].replace(0,df['MinTemp'].mean())

# %%
# lets check for zeros
count=(df==0).sum()
count
# Out:
# Date             0
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RainTomorrow     0
# dtype: int64

# %%
# there are some object type columns 
# lets encode them
from sklearn.preprocessing import LabelEncoder

# %%
lab_enc=LabelEncoder()

# %%
df2=lab_enc.fit_transform(df['Date'])
df['Date']=df2
df.head()
# Out:
#    Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0     0   Albury     13.4     22.9  0.600000     5.389395  7.632205
# 1     1   Albury      7.4     25.1  2.805913     5.389395  7.632205
# 2     2   Albury     12.9     25.7  2.805913     5.389395  7.632205
# 3     3   Albury      9.2     28.0  2.805913     5.389395  7.632205
# 4     4   Albury     17.5     32.3  1.000000     5.389395  7.632205
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df2=lab_enc.fit_transform(df['Location'])
df['Location']=df2
df.head()
# Out:
#    Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0     0         1     13.4     22.9  0.600000     5.389395  7.632205
# 1     1         1      7.4     25.1  2.805913     5.389395  7.632205
# 2     2         1     12.9     25.7  2.805913     5.389395  7.632205
# 3     3         1      9.2     28.0  2.805913     5.389395  7.632205
# 4     4         1     17.5     32.3  1.000000     5.389395  7.632205
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df2=lab_enc.fit_transform(df['WindGustDir'])
df['WindGustDir']=df2
df.head()
# Out:
#    Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0     0         1     13.4     22.9  0.600000     5.389395  7.632205
# 1     1         1      7.4     25.1  2.805913     5.389395  7.632205
# 2     2         1     12.9     25.7  2.805913     5.389395  7.632205
# 3     3         1      9.2     28.0  2.805913     5.389395  7.632205
# 4     4         1     17.5     32.3  1.000000     5.389395  7.632205
#
#    WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           13           44.0          W  ...        71.0         22.0
# 1           14           44.0        NNW  ...        44.0         25.0
# 2           15           46.0          W  ...        38.0         30.0
# 3            4           24.0         SE  ...        45.0         16.0
# 4           13           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df2=lab_enc.fit_transform(df['WindDir9am'])
df['WindDir9am']=df2
df.head()
# Out:
#    Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0     0         1     13.4     22.9  0.600000     5.389395  7.632205
# 1     1         1      7.4     25.1  2.805913     5.389395  7.632205
# 2     2         1     12.9     25.7  2.805913     5.389395  7.632205
# 3     3         1      9.2     28.0  2.805913     5.389395  7.632205
# 4     4         1     17.5     32.3  1.000000     5.389395  7.632205
#
#    WindGustDir  WindGustSpeed  WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           13           44.0          13  ...        71.0         22.0
# 1           14           44.0           6  ...        44.0         25.0
# 2           15           46.0          13  ...        38.0         30.0
# 3            4           24.0           9  ...        45.0         16.0
# 4           13           41.0           1  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df2=lab_enc.fit_transform(df['WindDir3pm'])
df['WindDir3pm']=df2
df.head()
# Out:
#    Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0     0         1     13.4     22.9  0.600000     5.389395  7.632205
# 1     1         1      7.4     25.1  2.805913     5.389395  7.632205
# 2     2         1     12.9     25.7  2.805913     5.389395  7.632205
# 3     3         1      9.2     28.0  2.805913     5.389395  7.632205
# 4     4         1     17.5     32.3  1.000000     5.389395  7.632205
#
#    WindGustDir  WindGustSpeed  WindDir9am  ...  Humidity9am  Humidity3pm  \
# 0           13           44.0          13  ...         71.0         22.0
# 1           14           44.0           6  ...         44.0         25.0
# 2           15           46.0          13  ...         38.0         30.0
# 3            4           24.0           9  ...         45.0         16.0
# 4           13           41.0           1  ...         82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df2=lab_enc.fit_transform(df['RainToday'])
df['RainToday']=df2
df.head()
# Out:
#    Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0     0         1     13.4     22.9  0.600000     5.389395  7.632205
# 1     1         1      7.4     25.1  2.805913     5.389395  7.632205
# 2     2         1     12.9     25.7  2.805913     5.389395  7.632205
# 3     3         1      9.2     28.0  2.805913     5.389395  7.632205
# 4     4         1     17.5     32.3  1.000000     5.389395  7.632205
#
#    WindGustDir  WindGustSpeed  WindDir9am  ...  Humidity9am  Humidity3pm  \
# 0           13           44.0          13  ...         71.0         22.0
# 1           14           44.0           6  ...         44.0         25.0
# 2           15           46.0          13  ...         38.0         30.0
# 3            4           24.0           9  ...         45.0         16.0
# 4           13           41.0           1  ...         82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df2=lab_enc.fit_transform(df['RainTomorrow'])
df['RainTomorrow']=df2
df.head()
# Out:
#    Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0     0         1     13.4     22.9  0.600000     5.389395  7.632205
# 1     1         1      7.4     25.1  2.805913     5.389395  7.632205
# 2     2         1     12.9     25.7  2.805913     5.389395  7.632205
# 3     3         1      9.2     28.0  2.805913     5.389395  7.632205
# 4     4         1     17.5     32.3  1.000000     5.389395  7.632205
#
#    WindGustDir  WindGustSpeed  WindDir9am  ...  Humidity9am  Humidity3pm  \
# 0           13           44.0          13  ...         71.0         22.0
# 1           14           44.0           6  ...         44.0         25.0
# 2           15           46.0          13  ...         38.0         30.0
# 3            4           24.0           9  ...         45.0         16.0
# 4           13           41.0           1  ...         82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
# checking the datatypes

# %%
df.dtypes
# Out:
# Date               int32
# Location           int32
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir        int32
# WindGustSpeed    float64
# WindDir9am         int32
# WindDir3pm         int32
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am      float64
# Humidity3pm      float64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp9am          float64
# Temp3pm          float64
# RainToday          int32
# RainTomorrow       int32
# dtype: object

# %%
# data visualization
# for that importing libraries
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df_1=df.copy()

# %%
# lets delete the date column as it is of no use
df=df_1.drop(columns=['Date'],inplace=True)

# %%
# data visualization
plt.figure(figsize=(22,30),facecolor='yellow')
plotnumber=1
for column in df_1:
    if plotnumber<=22:
        ax=plt.subplot(11,2,plotnumber)
        sns.distplot(df_1[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %%
df_1.skew()
# Out:
# Location         -0.050456
# MinTemp          -0.086839
# MaxTemp           0.380654
# Rainfall         14.354332
# Evaporation      14.080826
# Sunshine         -0.589182
# WindGustDir       0.119640
# WindGustSpeed     0.757000
# WindDir9am        0.172792
# WindDir3pm       -0.119847
# WindSpeed9am      1.198834
# WindSpeed3pm      0.614789
# Humidity9am      -0.256743
# Humidity3pm       0.118281
# Pressure9am      -0.024082
# Pressure3pm      -0.010214
# Cloud9am         -0.322508
# Cloud3pm         -0.222041
# Temp9am          -0.014748
# Temp3pm           0.397331
# RainToday         1.242362
# RainTomorrow      1.241588
# dtype: float64

# %%
# thera is lot of skewness in the dataset
#lets deal with it

# %%
# data outliers using boxplot
plt.figure(figsize=(22,30),facecolor='yellow')
plotnumber=1
for column in df_1:
    if plotnumber<=22:
        ax=plt.subplot(11,2,plotnumber)
        sns.boxplot(df_1[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %%
#lets remove the skewness using power transformer
from sklearn.preprocessing import PowerTransformer

# %%
scaler=PowerTransformer(method='yeo-johnson')

# %%
features=['Rainfall','Evaporation','WindGustSpeed','WindSpeed9am','RainToday']

# %%
df_1[features]=scaler.fit_transform(df_1[features].values)
df_1[features]
# Out:
#       Rainfall  Evaporation  WindGustSpeed  WindSpeed9am  RainToday
# 0    -1.770911     0.195278       0.380260      0.700367  -0.556099
# 1     0.020100     0.195278       0.380260     -1.587538  -0.556099
# 2     0.020100     0.195278       0.515699      0.609027  -0.556099
# 3     0.020100     0.195278      -1.265782     -0.286028  -0.556099
# 4    -1.251238     0.195278       0.169468     -0.922696  -0.556099
# ...        ...          ...            ...           ...        ...
# 8420  0.020100     0.195278      -0.614550     -0.027337  -0.556099
# 8421  0.020100     0.195278      -1.473608     -0.027337  -0.556099
# 8422  0.020100     0.195278      -0.127602     -0.579952  -0.556099
# 8423  0.020100     0.195278      -0.880853     -0.027337  -0.556099
# 8424  0.020100     0.195278       0.109734      0.415374  -0.556099
#
# [8425 rows x 5 columns]

# %%
df_1.skew()
# Out:
# Location        -0.050456
# MinTemp         -0.086839
# MaxTemp          0.380654
# Rainfall        -0.167125
# Evaporation      0.067936
# Sunshine        -0.589182
# WindGustDir      0.119640
# WindGustSpeed    0.010481
# WindDir9am       0.172792
# WindDir3pm      -0.119847
# WindSpeed9am    -0.011698
# WindSpeed3pm     0.614789
# Humidity9am     -0.256743
# Humidity3pm      0.118281
# Pressure9am     -0.024082
# Pressure3pm     -0.010214
# Cloud9am        -0.322508
# Cloud3pm        -0.222041
# Temp9am         -0.014748
# Temp3pm          0.397331
# RainToday        1.242362
# RainTomorrow     1.241588
# dtype: float64

# %%
# lets delete one column
df=df_1.drop(columns=['Temp3pm'],axis=1)

# %%
# lets train_test and split
# for that importing necessary libraries
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.metrics import accuracy_score,confusion_matrix,r2_score,classification_report
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVC
import xgboost as xgb
import warnings
warnings.filterwarnings('ignore')

# %%
# lets divide the dataset into label and features


x=df_1.drop(columns=['RainTomorrow'],axis=1)
y=df_1['RainTomorrow']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=355)

# %%
# training the model

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf=RandomForestClassifier(n_estimators=100,random_state=0)
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
def metric_score(clf,x_train,x_test,y_train,y_test,train=True):
    if train:
        y_pred=clf.predict(x_train)
        print("\n=======train result========")
        print(f"accuracy score:{accuracy_score(y_train,y_pred)*100:.2f}%")
    elif train==False:
        pred=clf.predict(x_test)
        print("\n===============test result===========")
        print(f"accuracy score:{accuracy_score(y_test,pred)*100:.2f}%")

# %%
# lets check the score
metric_score(rf,x_train,x_test,y_train,y_test,train=True)
metric_score(rf,x_train,x_test,y_train,y_test,train=False)
# Out:
# =======train result========
# accuracy score:99.98%
#
# ===============test result===========
# accuracy score:89.32%

# %%
y_test=y_test.values.reshape(-1,1)
print(y_test)
# Out:
# [[0]
#  [0]
#  [0]
#  ...
#  [0]
#  [0]
#  [0]]

# %%
y_pred=(rf.predict(x_test))

# %%
print(y_pred)
# Out:
# [0 0 0 ... 0 0 0]

# %%
#hyper parameter tuning
params={'n_estimators':[13,15],
       'criterion':['entropy','gini'],
       'max_depth':[10,15],
       'min_samples_split':[10,11],
       'min_samples_leaf':[5,6]}
grd=GridSearchCV(rf,param_grid=params)
grd.fit(x_train,y_train)
print(grd.best_params_)
# Out:
# {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 5, 'min_samples_split': 11, 'n_estimators': 15}

# %%
rf=grd.best_estimator_
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=15, min_samples_leaf=5,
#                        min_samples_split=11, n_estimators=15, random_state=0)

# %%
# lets check the score
metric_score(rf,x_train,x_test,y_train,y_test,train=True)
metric_score(rf,x_train,x_test,y_train,y_test,train=False)
# Out:
# =======train result========
# accuracy score:93.21%
#
# ===============test result===========
# accuracy score:86.33%

# %%
# check the ccuracy using another model
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
# lets check the score
metric_score(dt,x_train,x_test,y_train,y_test,train=True)
metric_score(dt,x_train,x_test,y_train,y_test,train=False)
# Out:
# =======train result========
# accuracy score:99.98%
#
# ===============test result===========
# accuracy score:85.19%

# %%
y_pred=(rf.predict(x_test))
print(y_pred)
# Out:
# [0 0 0 ... 0 0 0]

# %%
# saving the model

# %%
import pickle

# %%
pickle.dump(rf,open('rainfall','wb'))

# %%
loaded_model=pickle.load(open('rainfall','rb'))

# %%
result=loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# 86.3312766967252
