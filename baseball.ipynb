# %%
# importing necessary libraries
import pandas as pd
import numpy as np

# %%
# loading the dataset
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv')
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
#checking the shape
df.shape
# Out:
# (30, 17)

# %%
# lets check for nulls
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
# good there are no null values
# lets move further

# %%
#lets check the datatypes
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
# we can see there is continuous data but it is showing object datatype lets check

# %%
df['W'].unique()
# Out:
# array([ 95,  83,  81,  76,  74,  93,  87,  80,  78,  88,  86,  85,  68,
#        100,  98,  97,  64,  90,  71,  67,  63,  92,  84,  79], dtype=int64)

# %%
df['R'].unique()
# Out:
# array([724, 696, 669, 622, 689, 891, 764, 713, 644, 748, 751, 729, 661,
#        656, 694, 647, 697, 655, 640, 683, 703, 613, 573, 626, 667, 720,
#        650, 737], dtype=int64)

# %%
df['AB'].unique()
# Out:
# array([5575, 5467, 5439, 5533, 5605, 5509, 5567, 5485, 5640, 5511, 5459,
#        5417, 5544, 5600, 5484, 5631, 5491, 5480, 5571, 5527, 5428, 5463,
#        5420, 5529, 5385, 5565, 5649, 5457, 5572], dtype=int64)

# %%
df['H'].unique()
# Out:
# array([1497, 1349, 1395, 1381, 1515, 1480, 1397, 1370, 1383, 1495, 1419,
#        1363, 1331, 1379, 1405, 1386, 1462, 1341, 1378, 1382, 1351, 1420,
#        1361, 1374, 1346, 1486, 1494, 1324, 1479], dtype=int64)

# %%
df['2B'].unique()
# Out:
# array([300, 277, 303, 260, 289, 308, 272, 246, 278, 294, 279, 243, 262,
#        288, 292, 274, 257, 295, 265, 236, 251, 263], dtype=int64)

# %%
df['3B'].unique()
# Out:
# array([42, 44, 29, 27, 49, 17, 19, 20, 32, 33, 26, 21, 22, 46, 39, 30, 34,
#        13, 40, 18, 37, 48, 36], dtype=int64)

# %%
df['HR'].unique()
# Out:
# array([139, 156, 141, 136, 151, 232, 212, 217, 167, 161, 172, 230, 176,
#        198, 146, 137, 140, 171, 145, 177, 120, 100, 130, 187, 154, 148,
#        186], dtype=int64)

# %%
df['BB'].unique()
# Out:
# array([383, 439, 533, 404, 455, 570, 554, 418, 436, 478, 503, 486, 435,
#        475, 506, 461, 567, 412, 496, 488, 539, 375, 471, 387, 563, 457,
#        490, 426, 388], dtype=int64)

# %%
df['SO'].unique()
# Out:
# array([ 973, 1264, 1157, 1231, 1259, 1151, 1227, 1331, 1310, 1148, 1233,
#        1392, 1150, 1336, 1119, 1267, 1322, 1518, 1299, 1255, 1290, 1344,
#        1107, 1274, 1258, 1159, 1312, 1327, 1283], dtype=int64)

# %%
df['SB'].unique()
# Out:
# array([104,  70,  86,  68,  83,  88,  63,  44,  87,  71, 101, 121,  52,
#         69,  78,  98,  95,  84, 134,  51,  57, 112,  59,  93, 132,  82,
#         97], dtype=int64)

# %%
df['RA'].unique()
# Out:
# array([641, 700, 640, 701, 803, 670, 698, 693, 642, 753, 733, 618, 675,
#        726, 729, 525, 596, 608, 737, 754, 613, 635, 678, 760, 809, 595,
#        627, 713, 731, 844], dtype=int64)

# %%
df['ER'].unique()
# Out:
# array([601, 653, 584, 643, 746, 609, 652, 646, 604, 694, 680, 572, 630,
#        677, 664, 478, 532, 546, 682, 700, 557, 577, 638, 698, 749, 553,
#        597, 659, 655, 799], dtype=int64)

# %%
df['ERA'].unique()
# Out:
# array([3.73, 4.07, 3.67, 3.98, 4.64, 3.8 , 4.03, 4.05, 3.74, 4.31, 4.24,
#        3.57, 3.94, 4.16, 4.14, 2.94, 3.21, 3.36, 4.28, 4.33, 3.43, 3.62,
#        4.02, 4.41, 4.69, 3.44, 3.72, 4.04, 4.09, 5.04])

# %%
df['CG'].unique()
# Out:
# array([ 2, 11,  7,  3,  0,  1,  5,  6,  4], dtype=int64)

# %%
df['SHO'].unique()
# Out:
# array([ 8, 12, 10,  9,  4, 13, 15, 21,  7, 14, 18,  6], dtype=int64)

# %%
df['SV'].unique()
# Out:
# array([56, 45, 38, 37, 35, 34, 48, 43, 60, 40, 39, 46, 28, 62, 54, 50, 41,
#        44, 47, 36], dtype=int64)

# %%
df['E'].unique()
# Out:
# array([ 88,  86,  79, 101,  93,  77,  95,  97, 119,  85,  94, 126,  96,
#        122, 111, 116,  90, 117,  75,  78,  92], dtype=int64)

# %%
df['ERA'].dtypes
# Out:
# dtype('float64')

# %%
#lets check for zeros
zero=(df==0).sum()
zero
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     3
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
#lets see the description of the dataset
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
# to see the information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
# lets check the skewness of the dataset
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %%
#importing necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
plt.figure(figsize=(20,25),facecolor='yellow')
plotnumber=1
for column in df:
    if plotnumber<=16:
        ax=plt.subplot(4,4,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %%
plt.figure(figsize=(20,25),facecolor='yellow')
plotnumber=1
for column in df:
    if plotnumber<=16:
        ax=plt.subplot(4,4,plotnumber)
        sns.boxplot(df[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %%
# as we can see that there is no such skewness in the dataset
# lets move further

# %%
# lets see the correlation of columns with target column
#checking the correlation
df_corr=df.corr()
plt.figure(figsize=(25,20))
sns.heatmap(df_corr,annot=True)
plt.plot()
# Out:
# []

# %%
# as we can see that there is strong correlation between RAand Era
# also in RA and ER
#lets plot scatterplot to conform

# %%
df.plot(kind='scatter',x='RA',y='ER',figsize=(12,6))
# Out:
# <AxesSubplot:xlabel='RA', ylabel='ER'>

# %%
df.plot(kind='scatter',x='RA',y='ERA',figsize=(12,6))
# Out:
# <AxesSubplot:xlabel='RA', ylabel='ERA'>

# %%
#seperating the dataset into train and test
# for thaat import necessary libraries
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix,roc_curve,roc_auc_score
import warnings
warnings.filterwarnings('ignore')

# %%
x=df.drop('W',axis=1)
y=df["W"]

# %%
scaler=StandardScaler()
x_scaled=scaler.fit_transform(x)

# %%
x_scaled.shape
# Out:
# (30, 16)

# %%
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.25,random_state=40)

# %%
lr=LinearRegression()

# %%
#building model
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)
y_pred
# Out:
# array([81.74392307, 91.78146522, 67.98836661, 88.10757986, 95.11296831,
#        81.75102947, 82.90213656, 81.3091993 ])

# %%
# lets check model accuracy
# training accuracy
lr.score(x_train,y_train)
# Out:
# 0.9800859548728881

# %%
#testing score
lr.score(x_test,y_test)
# Out:
# 0.5185839070998172

# %%
y_pred=lr.predict(x_test)
y_pred
# Out:
# array([81.74392307, 91.78146522, 67.98836661, 88.10757986, 95.11296831,
#        81.75102947, 82.90213656, 81.3091993 ])

# %%
#lets plot and visualise
plt.scatter(y_test,y_pred)
plt.xlabel('actual ')
plt.ylabel('predicted')
plt.title('actual vs predicted')
plt.show()

# %%
# as we can see that testing score is very less 
#lets cross_validate the model
from sklearn.model_selection import cross_val_score,KFold

# %%
pred_train=lr.predict(x_train)
pred_test=lr.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
train_accuracy=r2_score(y_train,pred_train)
test_accuracy=r2_score(y_test,pred_test)

# %%
for i in range(2,10):
    cv_score=cross_val_score(lr,x,y,cv=i)
    cv_mean=cv_score.mean()
    print(f"at cross fold{i}the cvscore is{cv_mean}and accuracyscore for training is{train_accuracy}and accuracy for testing accuracy is{test_accuracy}" )
    print("\n")
# Out:
# at cross fold2the cvscore is-1.057932205834568and accuracyscore for training is0.9800859548728881and accuracy for testing accuracy is0.5185839070998172
#
#
# at cross fold3the cvscore is0.2258846016774and accuracyscore for training is0.9800859548728881and accuracy for testing accuracy is0.5185839070998172
#
#
# at cross fold4the cvscore is0.24952166654368527and accuracyscore for training is0.9800859548728881and accuracy for testing accuracy is0.5185839070998172
#
#
# at cross fold5the cvscore is0.04075540667465847and accuracyscore for training is0.9800859548728881and accuracy for testing accuracy is0.5185839070998172
#
#
# at cross fold6the cvscore is0.2515353093720216and accuracyscore for training is0.9800859548728881and accuracy for testing accuracy is0.5185839070998172
#
#
# at cross fold7the cvscore is0.3890804644289939and accuracyscore for training is0.9800859548728881and accuracy for testing accuracy is0.5185839070998172
#
#
# ...

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso

# %%
parameters={'alpha':[.0001,.001,.01,.1,1],
           'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 0.1, 'random_state': 0}

# %%
# fnal model training
ls=Lasso(alpha=1,random_state=0)
ls.fit(x_train,y_train)
ls_score_training=ls.score(x_train,y_train)
pred_ls=ls.predict(x_test)
ls_score_training*100
pred_ls=ls.predict(x_test)

# %%
lss=r2_score(y_test,pred_ls)
lss*100
# Out:
# 82.78474801523504

# %%
#enemble technique
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

# %%
parameters={'criterion':['mse','mae'],
           'max_features':["auto","sqrt","log2"]}
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'criterion': 'mse', 'max_features': 'sqrt'}

# %%
rf=RandomForestRegressor(criterion="mse",max_features="log2")
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
pred_decision=rf.predict(x_test)
rfs=r2_score(y_test,pred_decision)
print('r2_score',rfs*100)
rf_score=cross_val_score(rf,x,y,cv=5)
rfc=rf_score.mean()
print('cross val score:',rfc*100)
# Out:
# r2_score 50.85873571356326
# cross val score: -52.98664115017212

# %%
# it seems lasso is good for this dataset

# %%
# saving the model
import pickle

# %%
pickle.dump(ls,open('reg_mod','wb'))
loaded_model=pickle.load(open('reg_mod','rb'))

# %%
result=loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# 82.78474801523504
