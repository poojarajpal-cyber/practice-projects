# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("D:\dataset3-main\global_Power_plant_database.csv")
df.head()
# Out:
#   country country_long                      name   gppd_idnr  capacity_mw  \
# 0     IND        India          ACME Solar Tower  WRI1020239          2.5
# 1     IND        India       ADITYA CEMENT WORKS  WRI1019881         98.0
# 2     IND        India  AES Saurashtra Windfarms  WRI1026669         39.2
# 3     IND        India               AGARTALA GT  IND0000001        135.0
# 4     IND        India              AKALTARA TPP  IND0000002       1800.0
#
#    latitude  longitude primary_fuel other_fuel1 other_fuel2  ...  \
# 0   28.1839    73.2407        Solar         NaN         NaN  ...
# 1   24.7663    74.6090         Coal         NaN         NaN  ...
# 2   21.9038    69.3732         Wind         NaN         NaN  ...
# 3   23.8712    91.3602          Gas         NaN         NaN  ...
# 4   21.9603    82.4091         Coal         Oil         NaN  ...
#
#                      geolocation_source  wepp_id year_of_capacity_data  \
# ...

# %%
#checking the shaape
df.shape
# Out:
# (908, 25)

# %%
# checking for nulls
df.isnull().sum()
# Out:
# country                       0
# country_long                  0
# name                          0
# gppd_idnr                     0
# capacity_mw                   0
# latitude                     46
# longitude                    46
# primary_fuel                  0
# other_fuel1                 709
# other_fuel2                 907
# other_fuel3                 908
# commissioning_year          380
# owner                       566
# source                        0
# url                           0
# geolocation_source           19
# wepp_id                     908
# year_of_capacity_data       388
# generation_gwh_2013         524
# generation_gwh_2014         507
# generation_gwh_2015         483
# generation_gwh_2016         471
# generation_gwh_2017         465
# generation_data_source      458
# estimated_generation_gwh    908
# dtype: int64

# %%
#lets check the datatypes 
df.dtypes
# Out:
# country                      object
# country_long                 object
# name                         object
# gppd_idnr                    object
# capacity_mw                 float64
# latitude                    float64
# longitude                   float64
# primary_fuel                 object
# other_fuel1                  object
# other_fuel2                  object
# other_fuel3                 float64
# commissioning_year          float64
# owner                        object
# source                       object
# url                          object
# geolocation_source           object
# wepp_id                     float64
# year_of_capacity_data       float64
# generation_gwh_2013         float64
# generation_gwh_2014         float64
# generation_gwh_2015         float64
# generation_gwh_2016         float64
# generation_gwh_2017         float64
# generation_data_source       object
# estimated_generation_gwh    float64
# dtype: object

# %%
# checking the description
df.describe()
# Out:
#        capacity_mw    latitude   longitude  other_fuel3  commissioning_year  \
# count   908.000000  862.000000  862.000000          0.0          528.000000
# mean    321.046378   21.196189   77.447848          NaN         1996.876894
# std     580.221767    6.248627    4.907260          NaN           17.047817
# min       0.000000    8.168900   68.644700          NaN         1927.000000
# 25%      16.837500   16.771575   74.258975          NaN         1988.000000
# 50%      60.000000   21.778300   76.719250          NaN         2000.000000
# 75%     388.125000   25.516375   79.441475          NaN         2011.250000
# max    4760.000000   34.649000   95.408000          NaN         2018.000000
#
#        wepp_id  year_of_capacity_data  generation_gwh_2013  \
# count      0.0                  520.0           384.000000
# mean       NaN                 2018.0          2304.059202
# std        NaN                    0.0          3794.767492
# ...

# %%
df.tail()
# Out:
#     country country_long                          name   gppd_idnr  \
# 903     IND        India                  YERMARUS TPP  IND0000513
# 904     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 905     IND        India  Yelisirur wind power project  WRI1026776
# 906     IND        India                   ZAWAR MINES  WRI1019901
# 907     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel other_fuel1 other_fuel2  \
# 903       1600.0   16.2949    77.3568         Coal         Oil         NaN
# 904          3.0   12.8932    78.1654        Solar         NaN         NaN
# 905         25.5   15.2758    75.5811         Wind         NaN         NaN
# 906         80.0   24.3500    73.7477         Coal         NaN         NaN
# 907         16.5    9.9344    77.4768         Wind         NaN         NaN
#
#      ...  geolocation_source  wepp_id year_of_capacity_data  \
# ...

# %%
# as we can see that there are so many nulls in the dataset lets treat them

# %%
# as i can observe that some of the columns having all the null values lets delete them
df=df.drop(columns=['other_fuel2','other_fuel3','estimated_generation_gwh'],axis=1)

# %%
# lets deal with other null values

# %%
df['latitude']=df['latitude'].fillna(df['latitude'].mean())

# %%
df['longitude']=df['longitude'].fillna(df['longitude'].mean())
df['other_fuel1']=df['other_fuel1'].fillna(df['other_fuel1'].mode())

# %%
df['commissioning_year']=df['commissioning_year'].fillna(df['commissioning_year'].mode())

# %%
df['owner']=df['owner'].fillna(df['owner'].mode())

# %%
df['geolocation_source']=df['geolocation_source'].fillna(df['geolocation_source'].mode())

# %%
#the column wepp_id has all the null values 
# so lets delete the column

# %%
df=df.drop(columns=['wepp_id'],axis=1)

# %%
df['year_of_capacity_data']=df['year_of_capacity_data'].fillna(df['year_of_capacity_data'].mode())

# %%
df['generation_gwh_2013']=df['generation_gwh_2013'].fillna(df['generation_gwh_2013'].mean())
df['generation_gwh_2014']=df['generation_gwh_2014'].fillna(df['generation_gwh_2014'].mean())
df['generation_gwh_2015']=df['generation_gwh_2015'].fillna(df['generation_gwh_2015'].mean())
df['generation_gwh_2016']=df['generation_gwh_2016'].fillna(df['generation_gwh_2016'].mean())
df['generation_gwh_2017']=df['generation_gwh_2017'].fillna(df['generation_gwh_2017'].mean())

# %%
df['generation_data_source']=df['generation_data_source'].fillna(df['generation_data_source'].mode())

# %%
df.isnull().sum()
# Out:
# country                     0
# country_long                0
# name                        0
# gppd_idnr                   0
# capacity_mw                 0
# latitude                    0
# longitude                   0
# primary_fuel                0
# other_fuel1               708
# commissioning_year        380
# owner                     566
# source                      0
# url                         0
# geolocation_source         19
# year_of_capacity_data     387
# generation_gwh_2013         0
# generation_gwh_2014         0
# generation_gwh_2015         0
# generation_gwh_2016         0
# generation_gwh_2017         0
# generation_data_source    457
# dtype: int64

# %%
# count for zeros
df.count()
# Out:
# country                   908
# country_long              908
# name                      908
# gppd_idnr                 908
# capacity_mw               908
# latitude                  908
# longitude                 908
# primary_fuel              908
# other_fuel1               200
# commissioning_year        528
# owner                     342
# source                    908
# url                       908
# geolocation_source        889
# year_of_capacity_data     521
# generation_gwh_2013       908
# generation_gwh_2014       908
# generation_gwh_2015       908
# generation_gwh_2016       908
# generation_gwh_2017       908
# generation_data_source    451
# dtype: int64

# %%
#lets check
count=(df==0).sum()
count
# Out:
# country                    0
# country_long               0
# name                       0
# gppd_idnr                  0
# capacity_mw                1
# latitude                   0
# longitude                  0
# primary_fuel               0
# other_fuel1                0
# commissioning_year         0
# owner                      0
# source                     0
# url                        0
# geolocation_source         0
# year_of_capacity_data      0
# generation_gwh_2013       21
# generation_gwh_2014       28
# generation_gwh_2015       28
# generation_gwh_2016       31
# generation_gwh_2017       33
# generation_data_source     0
# dtype: int64

# %%
# lets fill zeros
df['generation_gwh_2017']=df['generation_gwh_2017'].replace(0,df['generation_gwh_2017'].mean())
df['generation_gwh_2016']=df['generation_gwh_2016'].replace(0,df['generation_gwh_2016'].mean())

df['generation_gwh_2015']=df['generation_gwh_2015'].replace(0,df['generation_gwh_2015'].mean())
df['generation_gwh_2014']=df['generation_gwh_2014'].replace(0,df['generation_gwh_2014'].mean())
df['generation_gwh_2013']=df['generation_gwh_2013'].replace(0,df['generation_gwh_2013'].mean())

# %%
df['capacity_mw']=df['capacity_mw'].replace(0,df['capacity_mw'].mean())

# %%
#lets check
count=(df==0).sum()
count
# Out:
# country                   0
# country_long              0
# name                      0
# gppd_idnr                 0
# capacity_mw               0
# latitude                  0
# longitude                 0
# primary_fuel              0
# other_fuel1               0
# commissioning_year        0
# owner                     0
# source                    0
# url                       0
# geolocation_source        0
# year_of_capacity_data     0
# generation_gwh_2013       0
# generation_gwh_2014       0
# generation_gwh_2015       0
# generation_gwh_2016       0
# generation_gwh_2017       0
# generation_data_source    0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# country                     0
# country_long                0
# name                        0
# gppd_idnr                   0
# capacity_mw                 0
# latitude                    0
# longitude                   0
# primary_fuel                0
# other_fuel1               708
# commissioning_year        380
# owner                     566
# source                      0
# url                         0
# geolocation_source         19
# year_of_capacity_data     387
# generation_gwh_2013         0
# generation_gwh_2014         0
# generation_gwh_2015         0
# generation_gwh_2016         0
# generation_gwh_2017         0
# generation_data_source    457
# dtype: int64

# %%
# let impute the null values
from sklearn.impute import SimpleImputer

# %%
si=SimpleImputer()

# %%
df['other_fuel1']=df['other_fuel1'].fillna('Oil')

# %%
df['commissioning_year']=df['commissioning_year'].fillna(df['commissioning_year'].median())

# %%
df['owner']=df['owner'].fillna('Central Electricity Authority')

# %%
df['geolocation_source']=df['geolocation_source'].fillna('WRI')

# %%
df['year_of_capacity_data']=df['year_of_capacity_data'].fillna(2019)

# %%
df['generation_data_source']=df['generation_data_source'].fillna('Central Electricity Authority')

# %%
df.isnull().sum()
# Out:
# country                   0
# country_long              0
# name                      0
# gppd_idnr                 0
# capacity_mw               0
# latitude                  0
# longitude                 0
# primary_fuel              0
# other_fuel1               0
# commissioning_year        0
# owner                     0
# source                    0
# url                       0
# geolocation_source        0
# year_of_capacity_data     0
# generation_gwh_2013       0
# generation_gwh_2014       0
# generation_gwh_2015       0
# generation_gwh_2016       0
# generation_gwh_2017       0
# generation_data_source    0
# dtype: int64

# %%
#now we have dealt with nulls lets move further
# Data Visualization

# %%
# importing necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
ax=sns.countplot(x='country',data=df)
print(df['country'].value_counts())
# Out:
# IND    908
# Name: country, dtype: int64

# %%
ax=sns.countplot(x='primary_fuel',data=df)
print(df['primary_fuel'].value_counts())
# Out:
# Coal       259
# Hydro      250
# Solar      127
# Wind       123
# Gas         69
# Biomass     50
# Oil         21
# Nuclear      9
# Name: primary_fuel, dtype: int64

# %%
df.dtypes
# Out:
# country                    object
# country_long               object
# name                       object
# gppd_idnr                  object
# capacity_mw               float64
# latitude                  float64
# longitude                 float64
# primary_fuel               object
# other_fuel1                object
# commissioning_year        float64
# owner                      object
# source                     object
# url                        object
# geolocation_source         object
# year_of_capacity_data     float64
# generation_gwh_2013       float64
# generation_gwh_2014       float64
# generation_gwh_2015       float64
# generation_gwh_2016       float64
# generation_gwh_2017       float64
# generation_data_source     object
# dtype: object

# %%
# as the dataset is object datatype
# lets encode it

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lab_enc=LabelEncoder()

# %%
df2=lab_enc.fit_transform(df['country'])
df['country']=df2
df.head()
# Out:
#    country country_long                      name   gppd_idnr  capacity_mw  \
# 0        0        India          ACME Solar Tower  WRI1020239          2.5
# 1        0        India       ADITYA CEMENT WORKS  WRI1019881         98.0
# 2        0        India  AES Saurashtra Windfarms  WRI1026669         39.2
# 3        0        India               AGARTALA GT  IND0000001        135.0
# 4        0        India              AKALTARA TPP  IND0000002       1800.0
#
#    latitude  longitude primary_fuel other_fuel1  commissioning_year  ...  \
# 0   28.1839    73.2407        Solar         Oil              2011.0  ...
# 1   24.7663    74.6090         Coal         Oil              2000.0  ...
# 2   21.9038    69.3732         Wind         Oil              2000.0  ...
# 3   23.8712    91.3602          Gas         Oil              2004.0  ...
# 4   21.9603    82.4091         Coal         Oil              2015.0  ...
#
#                                  source  \
# ...

# %%
df2=lab_enc.fit_transform(df['country_long'])
df['country_long']=df2
df.head()
# Out:
#    country  country_long                      name   gppd_idnr  capacity_mw  \
# 0        0             0          ACME Solar Tower  WRI1020239          2.5
# 1        0             0       ADITYA CEMENT WORKS  WRI1019881         98.0
# 2        0             0  AES Saurashtra Windfarms  WRI1026669         39.2
# 3        0             0               AGARTALA GT  IND0000001        135.0
# 4        0             0              AKALTARA TPP  IND0000002       1800.0
#
#    latitude  longitude primary_fuel other_fuel1  commissioning_year  ...  \
# 0   28.1839    73.2407        Solar         Oil              2011.0  ...
# 1   24.7663    74.6090         Coal         Oil              2000.0  ...
# 2   21.9038    69.3732         Wind         Oil              2000.0  ...
# 3   23.8712    91.3602          Gas         Oil              2004.0  ...
# 4   21.9603    82.4091         Coal         Oil              2015.0  ...
#
#                                  source  \
# ...

# %%
df2=lab_enc.fit_transform(df['name'])
df['name']=df2
df.head()
# Out:
#    country  country_long  name   gppd_idnr  capacity_mw  latitude  longitude  \
# 0        0             0     0  WRI1020239          2.5   28.1839    73.2407
# 1        0             0     1  WRI1019881         98.0   24.7663    74.6090
# 2        0             0     2  WRI1026669         39.2   21.9038    69.3732
# 3        0             0     3  IND0000001        135.0   23.8712    91.3602
# 4        0             0     4  IND0000002       1800.0   21.9603    82.4091
#
#   primary_fuel other_fuel1  commissioning_year  ...  \
# 0        Solar         Oil              2011.0  ...
# 1         Coal         Oil              2000.0  ...
# 2         Wind         Oil              2000.0  ...
# 3          Gas         Oil              2004.0  ...
# 4         Coal         Oil              2015.0  ...
#
#                                  source  \
# 0  National Renewable Energy Laboratory
# 1                  Ultratech Cement ltd
# 2                                   CDM
# ...

# %%
df2=lab_enc.fit_transform(df['gppd_idnr'])
df['gppd_idnr']=df2
df.head()
# Out:
#    country  country_long  name  gppd_idnr  capacity_mw  latitude  longitude  \
# 0        0             0     0        658          2.5   28.1839    73.2407
# 1        0             0     1        520         98.0   24.7663    74.6090
# 2        0             0     2        854         39.2   21.9038    69.3732
# 3        0             0     3          0        135.0   23.8712    91.3602
# 4        0             0     4          1       1800.0   21.9603    82.4091
#
#   primary_fuel other_fuel1  commissioning_year  ...  \
# 0        Solar         Oil              2011.0  ...
# 1         Coal         Oil              2000.0  ...
# 2         Wind         Oil              2000.0  ...
# 3          Gas         Oil              2004.0  ...
# 4         Coal         Oil              2015.0  ...
#
#                                  source  \
# 0  National Renewable Energy Laboratory
# 1                  Ultratech Cement ltd
# 2                                   CDM
# ...

# %%
df2=lab_enc.fit_transform(df['primary_fuel'])
df['primary_fuel']=df2
df.head()
# Out:
#    country  country_long  name  gppd_idnr  capacity_mw  latitude  longitude  \
# 0        0             0     0        658          2.5   28.1839    73.2407
# 1        0             0     1        520         98.0   24.7663    74.6090
# 2        0             0     2        854         39.2   21.9038    69.3732
# 3        0             0     3          0        135.0   23.8712    91.3602
# 4        0             0     4          1       1800.0   21.9603    82.4091
#
#    primary_fuel other_fuel1  commissioning_year  ...  \
# 0             6         Oil              2011.0  ...
# 1             1         Oil              2000.0  ...
# 2             7         Oil              2000.0  ...
# 3             2         Oil              2004.0  ...
# 4             1         Oil              2015.0  ...
#
#                                  source  \
# 0  National Renewable Energy Laboratory
# 1                  Ultratech Cement ltd
# 2                                   CDM
# ...

# %%
df2=lab_enc.fit_transform(df['other_fuel1'])
df['other_fuel1']=df2
df.head()
# Out:
#    country  country_long  name  gppd_idnr  capacity_mw  latitude  longitude  \
# 0        0             0     0        658          2.5   28.1839    73.2407
# 1        0             0     1        520         98.0   24.7663    74.6090
# 2        0             0     2        854         39.2   21.9038    69.3732
# 3        0             0     3          0        135.0   23.8712    91.3602
# 4        0             0     4          1       1800.0   21.9603    82.4091
#
#    primary_fuel  other_fuel1  commissioning_year  ...  \
# 0             6            2              2011.0  ...
# 1             1            2              2000.0  ...
# 2             7            2              2000.0  ...
# 3             2            2              2004.0  ...
# 4             1            2              2015.0  ...
#
#                                  source  \
# 0  National Renewable Energy Laboratory
# 1                  Ultratech Cement ltd
# 2                                   CDM
# ...

# %%
df2=lab_enc.fit_transform(df['owner'])
df['owner']=df2
df.head()
# Out:
#    country  country_long  name  gppd_idnr  capacity_mw  latitude  longitude  \
# 0        0             0     0        658          2.5   28.1839    73.2407
# 1        0             0     1        520         98.0   24.7663    74.6090
# 2        0             0     2        854         39.2   21.9038    69.3732
# 3        0             0     3          0        135.0   23.8712    91.3602
# 4        0             0     4          1       1800.0   21.9603    82.4091
#
#    primary_fuel  other_fuel1  commissioning_year  ...  \
# 0             6            2              2011.0  ...
# 1             1            2              2000.0  ...
# 2             7            2              2000.0  ...
# 3             2            2              2004.0  ...
# 4             1            2              2015.0  ...
#
#                                  source  \
# 0  National Renewable Energy Laboratory
# 1                  Ultratech Cement ltd
# 2                                   CDM
# ...

# %%
df2=lab_enc.fit_transform(df['source'])
df['source']=df2
df.head()
# Out:
#    country  country_long  name  gppd_idnr  capacity_mw  latitude  longitude  \
# 0        0             0     0        658          2.5   28.1839    73.2407
# 1        0             0     1        520         98.0   24.7663    74.6090
# 2        0             0     2        854         39.2   21.9038    69.3732
# 3        0             0     3          0        135.0   23.8712    91.3602
# 4        0             0     4          1       1800.0   21.9603    82.4091
#
#    primary_fuel  other_fuel1  commissioning_year  ...  source  \
# 0             6            2              2011.0  ...     109
# 1             1            2              2000.0  ...     174
# 2             7            2              2000.0  ...      21
# 3             2            2              2004.0  ...      22
# 4             1            2              2015.0  ...      22
#
#                                                  url  \
# 0  http://www.nrel.gov/csp/solarpaces/project_det...
# ...

# %%
df2=lab_enc.fit_transform(df['url'])
df['url']=df2
df.head()
# Out:
#    country  country_long  name  gppd_idnr  capacity_mw  latitude  longitude  \
# 0        0             0     0        658          2.5   28.1839    73.2407
# 1        0             0     1        520         98.0   24.7663    74.6090
# 2        0             0     2        854         39.2   21.9038    69.3732
# 3        0             0     3          0        135.0   23.8712    91.3602
# 4        0             0     4          1       1800.0   21.9603    82.4091
#
#    primary_fuel  other_fuel1  commissioning_year  ...  source  url  \
# 0             6            2              2011.0  ...     109  128
# 1             1            2              2000.0  ...     174  173
# 2             7            2              2000.0  ...      21  205
# 3             2            2              2004.0  ...      22   58
# 4             1            2              2015.0  ...      22   58
#
#                      geolocation_source year_of_capacity_data  \
# ...

# %%
df2=lab_enc.fit_transform(df['geolocation_source'])
df['geolocation_source']=df2
df.head()
# Out:
#    country  country_long  name  gppd_idnr  capacity_mw  latitude  longitude  \
# 0        0             0     0        658          2.5   28.1839    73.2407
# 1        0             0     1        520         98.0   24.7663    74.6090
# 2        0             0     2        854         39.2   21.9038    69.3732
# 3        0             0     3          0        135.0   23.8712    91.3602
# 4        0             0     4          1       1800.0   21.9603    82.4091
#
#    primary_fuel  other_fuel1  commissioning_year  ...  source  url  \
# 0             6            2              2011.0  ...     109  128
# 1             1            2              2000.0  ...     174  173
# 2             7            2              2000.0  ...      21  205
# 3             2            2              2004.0  ...      22   58
# 4             1            2              2015.0  ...      22   58
#
#    geolocation_source  year_of_capacity_data  generation_gwh_2013  \
# ...

# %%
df2=lab_enc.fit_transform(df['generation_data_source'])
df['generation_data_source']=df2
df.head()
# Out:
#    country  country_long  name  gppd_idnr  capacity_mw  latitude  longitude  \
# 0        0             0     0        658          2.5   28.1839    73.2407
# 1        0             0     1        520         98.0   24.7663    74.6090
# 2        0             0     2        854         39.2   21.9038    69.3732
# 3        0             0     3          0        135.0   23.8712    91.3602
# 4        0             0     4          1       1800.0   21.9603    82.4091
#
#    primary_fuel  other_fuel1  commissioning_year  ...  source  url  \
# 0             6            2              2011.0  ...     109  128
# 1             1            2              2000.0  ...     174  173
# 2             7            2              2000.0  ...      21  205
# 3             2            2              2004.0  ...      22   58
# 4             1            2              2015.0  ...      22   58
#
#    geolocation_source  year_of_capacity_data  generation_gwh_2013  \
# ...

# %%
# now that we have encoded the data lets move further
df.dtypes
# Out:
# country                     int32
# country_long                int32
# name                        int32
# gppd_idnr                   int32
# capacity_mw               float64
# latitude                  float64
# longitude                 float64
# primary_fuel                int32
# other_fuel1                 int32
# commissioning_year        float64
# owner                       int32
# source                      int32
# url                         int32
# geolocation_source          int32
# year_of_capacity_data     float64
# generation_gwh_2013       float64
# generation_gwh_2014       float64
# generation_gwh_2015       float64
# generation_gwh_2016       float64
# generation_gwh_2017       float64
# generation_data_source      int32
# dtype: object

# %%
# lets check the skewness
df.skew()
# Out:
# country                    0.000000
# country_long               0.000000
# name                       0.000000
# gppd_idnr                  0.000000
# capacity_mw                3.193231
# latitude                  -0.147391
# longitude                  1.129836
# primary_fuel               0.471141
# other_fuel1              -20.464435
# commissioning_year        -1.650230
# owner                      1.501604
# source                     1.829145
# url                        1.512258
# geolocation_source        -2.161710
# year_of_capacity_data      0.298916
# generation_gwh_2013        5.362261
# generation_gwh_2014        5.185913
# generation_gwh_2015        5.495284
# generation_gwh_2016        5.207006
# generation_gwh_2017        5.265460
# generation_data_source     0.000000
# dtype: float64

# %%
df.shape
# Out:
# (908, 21)

# %%
plt.figure(figsize=(20,25),facecolor='yellow')
plotnumber=1
for column in df:
    if plotnumber<=21:
        ax=plt.subplot(7,3,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %%
# lets check for outliers using boxplot
plt.figure(figsize=(20,25),facecolor='yellow')
plotnumber=1
for column in df:
    if plotnumber<=21:
        ax=plt.subplot(7,3,plotnumber)
        sns.boxplot(df[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %%
# apply log transformation on skewed data

# %%
import numpy as np

# %%
df['capacity_mw']=np.log(df['capacity_mw'])

# %%
df['longitude']=np.log(df['longitude'])
df['generation_gwh_2013']=np.log(df['generation_gwh_2013'])
df['generation_gwh_2014']=np.log(df['generation_gwh_2014'])
df['generation_gwh_2015']=np.log(df['generation_gwh_2015'])
df['generation_gwh_2016']=np.log(df['generation_gwh_2016'])
df['generation_gwh_2017']=np.log(df['generation_gwh_2017'])

# %%
df.skew()
# Out:
# country                    0.000000
# country_long               0.000000
# name                       0.000000
# gppd_idnr                  0.000000
# capacity_mw                0.007829
# latitude                  -0.147391
# longitude                  0.921567
# primary_fuel               0.471141
# other_fuel1              -20.464435
# commissioning_year        -1.650230
# owner                      1.501604
# source                     1.829145
# url                        1.512258
# geolocation_source        -2.161710
# year_of_capacity_data      0.298916
# generation_gwh_2013       -2.626458
# generation_gwh_2014       -2.558446
# generation_gwh_2015       -2.218797
# generation_gwh_2016       -1.927521
# generation_gwh_2017       -2.030487
# generation_data_source     0.000000
# dtype: float64

# %%
# lets check for outliers using boxplot
plt.figure(figsize=(20,25),facecolor='yellow')
plotnumber=1
for column in df:
    if plotnumber<=21:
        ax=plt.subplot(7,3,plotnumber)
        sns.boxplot(df[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %%
from sklearn.preprocessing import PowerTransformer

# %%
features=['generation_gwh_2017','generation_gwh_2016','generation_gwh_2015','generation_gwh_2014','generation_gwh_2013','geolocation_source','url','source','owner','commissioning_year','other_fuel1','longitude']

# %%
scaler=PowerTransformer(method='yeo-johnson')
df[features]=scaler.fit_transform(df[features].values)

# %%
# lets check for outliers using boxplot
plt.figure(figsize=(20,25),facecolor='yellow')
plotnumber=1
for column in df[features]:
    if plotnumber<=12:
        ax=plt.subplot(4,3,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %%
df.skew()
# Out:
# country                    0.000000
# country_long               0.000000
# name                       0.000000
# gppd_idnr                  0.000000
# capacity_mw                0.007829
# latitude                  -0.147391
# longitude                  0.000000
# primary_fuel               0.471141
# other_fuel1              -17.339637
# commissioning_year        -0.426588
# owner                     -0.067711
# source                    -0.214850
# url                        0.064612
# geolocation_source        -2.134586
# year_of_capacity_data      0.298916
# generation_gwh_2013        0.045996
# generation_gwh_2014        0.013587
# generation_gwh_2015       -0.069399
# generation_gwh_2016       -0.021714
# generation_gwh_2017       -0.077063
# generation_data_source     0.000000
# dtype: float64

# %%
#now that we have dealt with skewness to great extent
#split the data into features and target
x=df.drop(columns=['primary_fuel'])
y=df['primary_fuel']

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix,roc_auc_score
from sklearn.linear_model import LogisticRegression

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=355)

# %%
log_reg=LogisticRegression()

# %%
log_reg.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=log_reg.predict(x_test)
y_pred
# Out:
# array([3, 3, 3, 7, 1, 3, 3, 6, 1, 7, 3, 6, 7, 3, 3, 3, 1, 7, 3, 1, 3, 1,
#        3, 7, 3, 1, 3, 3, 7, 3, 3, 3, 3, 3, 0, 3, 3, 6, 6, 1, 7, 3, 3, 3,
#        3, 3, 3, 0, 6, 7, 1, 3, 3, 3, 3, 7, 1, 3, 6, 7, 7, 3, 1, 3, 3, 1,
#        6, 3, 6, 3, 6, 3, 1, 0, 6, 1, 6, 1, 3, 3, 1, 3, 3, 3, 3, 3, 6, 7,
#        3, 7, 7, 3, 3, 3, 3, 7, 3, 7, 6, 6, 1, 1, 6, 1, 6, 3, 3, 3, 3, 7,
#        7, 1, 3, 3, 3, 3, 3, 1, 6, 1, 3, 3, 1, 7, 3, 7, 6, 3, 1, 3, 3, 3,
#        3, 7, 1, 1, 6, 3, 3, 3, 3, 3, 3, 3, 7, 3, 1, 3, 3, 1, 3, 3, 3, 3,
#        6, 3, 3, 1, 6, 1, 3, 3, 3, 6, 1, 7, 3, 3, 7, 6, 3, 3, 1, 3, 3, 3,
#        6, 3, 3, 3, 3, 3, 1, 1, 3, 6, 3, 3, 3, 1, 6, 1, 1, 3, 3, 6, 1, 3,
#        7, 7, 3, 3, 3, 3, 1, 3, 6, 7, 3, 7, 3, 3, 3, 1, 6, 3, 3, 3, 3, 6,
#        3, 6, 6, 1, 1, 7, 1])

# %%
pred=log_reg.predict(x_train)
pred
# Out:
# array([3, 7, 3, 3, 3, 3, 1, 3, 1, 6, 3, 3, 1, 1, 1, 0, 3, 3, 1, 1, 1, 1,
#        1, 3, 1, 3, 7, 3, 1, 3, 1, 3, 3, 3, 3, 3, 6, 6, 3, 1, 6, 3, 3, 3,
#        7, 3, 3, 6, 3, 3, 3, 1, 6, 1, 3, 6, 7, 3, 7, 6, 1, 6, 3, 3, 7, 3,
#        7, 1, 6, 1, 1, 1, 1, 6, 3, 6, 3, 1, 3, 3, 7, 6, 3, 3, 1, 3, 6, 6,
#        6, 3, 1, 6, 3, 7, 3, 3, 3, 7, 3, 7, 1, 6, 3, 3, 6, 6, 3, 3, 3, 3,
#        1, 3, 6, 3, 3, 3, 6, 3, 3, 1, 3, 3, 3, 3, 6, 3, 1, 7, 3, 3, 3, 7,
#        3, 3, 3, 1, 3, 3, 6, 3, 3, 7, 7, 1, 3, 3, 3, 3, 3, 6, 3, 3, 3, 1,
#        3, 3, 3, 3, 3, 3, 3, 1, 1, 3, 1, 3, 7, 3, 3, 6, 3, 1, 7, 6, 3, 1,
#        7, 6, 7, 3, 3, 6, 1, 7, 3, 6, 1, 7, 6, 7, 3, 1, 3, 7, 3, 3, 3, 1,
#        3, 3, 7, 7, 1, 1, 3, 3, 1, 1, 6, 1, 3, 6, 6, 0, 1, 3, 1, 1, 3, 3,
#        3, 1, 3, 7, 6, 3, 3, 0, 7, 3, 3, 3, 1, 7, 3, 6, 1, 7, 1, 7, 0, 3,
#        7, 3, 3, 6, 3, 3, 3, 0, 3, 6, 1, 3, 3, 6, 7, 3, 6, 3, 3, 3, 3, 1,
#        3, 1, 6, 7, 3, 6, 1, 6, 6, 3, 3, 3, 3, 3, 1, 7, 6, 1, 3, 7, 3, 1,
# ...

# %%
accuracy=accuracy_score(y_train,pred)
accuracy
# Out:
# 0.5506607929515418

# %%
accur=accuracy_score(y_test,y_pred)
accur
# Out:
# 0.5550660792951542

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
def metric_score(clf,x_train,y_train,x_test,y_test,train=True):
    if train:
        y_pred=clf.predict(x_train)
        print("======train result=========")
        print(f"accuracy score:{accuracy_score(y_train,y_pred)*100:.2f}%")
         
   
    elif train==False:
        pred=clf.predict(x_test)
        print("\n==========test result===========")
        print(f"accuracy score:{accuracy_score(y_test,pred)*100:.2f}%")

# %%
knn=KNeighborsClassifier()
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred=knn.predict(x_test)
y_pred
# Out:
# array([1, 3, 3, 6, 0, 3, 1, 6, 1, 6, 1, 6, 7, 2, 3, 3, 3, 7, 1, 1, 3, 3,
#        3, 7, 3, 1, 3, 2, 6, 1, 3, 3, 1, 3, 1, 1, 2, 7, 6, 1, 7, 1, 3, 1,
#        3, 1, 3, 1, 6, 6, 1, 1, 1, 1, 2, 7, 0, 1, 7, 6, 7, 1, 1, 1, 1, 3,
#        6, 1, 6, 1, 7, 3, 0, 5, 6, 0, 7, 1, 1, 3, 1, 1, 3, 3, 3, 1, 6, 7,
#        3, 7, 6, 1, 1, 3, 3, 7, 1, 7, 6, 7, 1, 1, 6, 1, 6, 1, 1, 3, 3, 6,
#        7, 1, 1, 1, 1, 1, 3, 1, 7, 1, 1, 1, 1, 6, 3, 7, 7, 1, 1, 3, 1, 3,
#        1, 6, 2, 1, 7, 3, 3, 3, 3, 3, 1, 1, 6, 1, 1, 3, 3, 1, 2, 1, 1, 3,
#        6, 3, 3, 1, 6, 0, 3, 3, 1, 6, 0, 6, 3, 3, 7, 6, 1, 3, 0, 3, 2, 3,
#        6, 1, 3, 1, 3, 3, 2, 1, 2, 6, 3, 3, 1, 1, 6, 1, 0, 1, 3, 6, 1, 1,
#        6, 7, 3, 3, 3, 3, 1, 3, 6, 7, 1, 7, 1, 1, 2, 0, 6, 3, 1, 1, 1, 6,
#        3, 0, 6, 1, 2, 7, 1])

# %%
pred=knn.predict(x_train)
pred
# Out:
# array([1, 7, 3, 1, 2, 2, 1, 1, 0, 6, 1, 1, 0, 0, 0, 1, 1, 1, 0, 3, 3, 0,
#        1, 3, 0, 3, 6, 3, 1, 1, 1, 3, 1, 1, 1, 1, 7, 7, 2, 0, 7, 1, 3, 3,
#        7, 3, 1, 6, 1, 3, 3, 2, 6, 1, 1, 6, 7, 3, 7, 6, 1, 7, 3, 3, 7, 1,
#        7, 0, 6, 0, 0, 1, 0, 6, 2, 6, 1, 1, 1, 3, 7, 7, 1, 1, 1, 3, 6, 6,
#        6, 3, 1, 6, 1, 7, 3, 1, 3, 7, 3, 7, 0, 6, 1, 1, 7, 6, 1, 3, 2, 1,
#        1, 1, 6, 3, 1, 1, 6, 1, 3, 1, 3, 1, 3, 3, 7, 3, 1, 7, 3, 1, 3, 7,
#        1, 1, 3, 0, 1, 3, 6, 3, 3, 6, 7, 1, 3, 3, 3, 1, 2, 6, 1, 3, 1, 1,
#        3, 1, 1, 2, 3, 1, 3, 1, 0, 1, 1, 1, 7, 3, 3, 6, 3, 0, 6, 6, 3, 0,
#        7, 6, 7, 1, 3, 7, 1, 7, 1, 6, 1, 7, 7, 6, 3, 1, 3, 6, 2, 2, 1, 1,
#        3, 3, 6, 6, 1, 1, 1, 1, 0, 1, 6, 1, 1, 7, 6, 1, 1, 1, 0, 3, 1, 1,
#        3, 0, 1, 7, 6, 2, 3, 1, 7, 1, 2, 3, 1, 7, 3, 6, 1, 7, 1, 7, 1, 1,
#        7, 2, 3, 6, 1, 1, 1, 1, 1, 6, 1, 3, 3, 7, 7, 2, 6, 1, 1, 1, 3, 0,
#        2, 1, 7, 6, 1, 7, 2, 6, 6, 1, 3, 3, 3, 2, 1, 7, 7, 1, 2, 7, 2, 2,
# ...

# %%
accuracy=accuracy_score(y_train,pred)
accuracy
# Out:
# 0.7312775330396476

# %%
accur=accuracy_score(y_test,y_pred)
accur
# Out:
# 0.6299559471365639

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid={'algorithm':['kd_tree','brute'],
           'leaf_size':[3,5,6,7,8],
           'n_neighbors':[3,5,7,9,11,13]}
gridsearch=GridSearchCV(estimator=knn,param_grid=param_grid)
gridsearch.fit(x_train,y_train)
gridsearch.best_params_
# Out:
# {'algorithm': 'kd_tree', 'leaf_size': 3, 'n_neighbors': 3}

# %%
knn=KNeighborsClassifier(algorithm='kd_tree',leaf_size=3,n_neighbors=3)
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='kd_tree', leaf_size=3, n_neighbors=3)

# %%
y_pred=knn.predict(x_test)
y_pred
# Out:
# array([1, 1, 3, 6, 0, 3, 3, 6, 1, 6, 1, 6, 7, 2, 3, 3, 1, 7, 1, 1, 3, 3,
#        3, 7, 3, 1, 3, 2, 6, 1, 2, 3, 1, 1, 1, 1, 2, 7, 6, 1, 7, 1, 3, 1,
#        1, 1, 1, 0, 6, 6, 1, 1, 3, 1, 2, 7, 1, 1, 7, 6, 7, 1, 1, 1, 1, 3,
#        6, 1, 6, 1, 7, 3, 0, 5, 6, 0, 7, 1, 1, 1, 1, 1, 3, 3, 3, 1, 6, 7,
#        3, 7, 7, 1, 1, 3, 1, 7, 3, 7, 6, 7, 1, 1, 6, 1, 6, 1, 1, 3, 3, 6,
#        7, 1, 1, 1, 2, 1, 3, 1, 7, 1, 1, 1, 1, 6, 3, 7, 7, 1, 1, 3, 1, 3,
#        3, 6, 3, 1, 5, 3, 3, 3, 3, 3, 1, 1, 6, 1, 1, 3, 3, 1, 2, 1, 1, 2,
#        6, 3, 3, 1, 6, 0, 3, 3, 1, 6, 0, 6, 3, 3, 7, 6, 2, 3, 0, 3, 1, 3,
#        6, 1, 2, 1, 3, 3, 3, 1, 2, 6, 3, 3, 1, 1, 6, 1, 0, 2, 3, 6, 1, 1,
#        6, 7, 3, 3, 1, 3, 1, 1, 6, 7, 1, 7, 1, 1, 1, 1, 6, 3, 1, 1, 1, 6,
#        3, 0, 6, 1, 1, 7, 0])

# %%
pred=knn.predict(x_train)
pred
# Out:
# array([1, 7, 3, 1, 1, 2, 1, 1, 0, 6, 3, 1, 0, 0, 0, 0, 1, 1, 0, 2, 3, 0,
#        1, 3, 0, 3, 6, 3, 1, 3, 1, 3, 1, 1, 3, 1, 7, 7, 3, 0, 7, 1, 3, 3,
#        7, 3, 3, 6, 1, 1, 3, 2, 6, 3, 1, 6, 7, 3, 7, 6, 1, 7, 1, 3, 7, 1,
#        7, 0, 6, 0, 0, 1, 0, 6, 1, 6, 1, 1, 1, 1, 7, 5, 3, 1, 1, 1, 6, 6,
#        6, 3, 1, 6, 1, 7, 3, 1, 3, 7, 3, 7, 1, 6, 1, 1, 1, 6, 1, 3, 1, 1,
#        1, 3, 6, 3, 1, 1, 6, 5, 3, 0, 3, 1, 3, 3, 7, 1, 1, 7, 3, 1, 3, 7,
#        1, 1, 1, 0, 1, 3, 1, 3, 3, 6, 7, 5, 3, 3, 3, 1, 3, 6, 2, 3, 1, 1,
#        3, 3, 1, 3, 1, 1, 3, 1, 1, 1, 1, 3, 7, 1, 3, 7, 3, 1, 6, 6, 1, 5,
#        7, 6, 7, 1, 1, 7, 1, 7, 1, 6, 1, 7, 7, 6, 3, 5, 3, 6, 2, 2, 1, 1,
#        3, 3, 6, 6, 1, 0, 1, 1, 0, 1, 6, 3, 1, 7, 6, 0, 1, 3, 0, 3, 5, 1,
#        1, 0, 1, 7, 6, 2, 3, 1, 7, 1, 3, 3, 1, 7, 3, 6, 1, 7, 1, 7, 7, 3,
#        7, 2, 1, 6, 1, 1, 1, 6, 3, 6, 1, 1, 3, 7, 7, 3, 6, 1, 1, 1, 3, 0,
#        1, 1, 7, 6, 1, 7, 2, 6, 6, 1, 3, 3, 3, 1, 1, 7, 5, 1, 2, 7, 2, 2,
# ...

# %%
accuracy=accuracy_score(y_train,pred)
accuracy
# Out:
# 0.7929515418502202

# %%
accur=accuracy_score(y_test,y_pred)
accur
# Out:
# 0.6387665198237885

# %%
# lets take capacity mw as target variable

# %%
df.head()
# Out:
#    country  country_long  name  gppd_idnr  capacity_mw  latitude  \
# 0        0             0     0        658     0.916291   28.1839
# 1        0             0     1        520     4.584967   24.7663
# 2        0             0     2        854     3.668677   21.9038
# 3        0             0     3          0     4.905275   23.8712
# 4        0             0     4          1     7.495542   21.9603
#
#       longitude  primary_fuel  other_fuel1  commissioning_year  ...    source  \
# 0 -3.261280e-16             6     0.057575            1.171040  ...  1.583885
# 1 -1.942890e-16             1     0.057575            0.011278  ...  2.037695
# 2 -7.771561e-16             7     0.057575            0.011278  ... -0.471579
# 3  7.979728e-16             2     0.057575            0.399644  ... -0.402909
# 4  3.885781e-16             1     0.057575            1.670473  ... -0.402909
#
#         url  geolocation_source  year_of_capacity_data  generation_gwh_2013  \
# ...

# %%
# splitting the datasetinto features and target
#now that we have dealt with skewness to great extent

x=df.drop(columns=['capacity_mw'])
y=df['capacity_mw']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=355)

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.metrics import r2_score

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred_train=lr.predict(x_train)
pred_test=lr.predict(x_test)
print(f"training score{r2_score(y_train,pred_train)}")
print(f"testing score{r2_score(y_test,pred_test)}")
# Out:
# training score0.5947212631448149
# testing score0.5312934427163701

# %%
from sklearn.linear_model import Lasso

# %%
parameters={'alpha':[.0001,.001,.01,.1,1],
           'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 0.01, 'random_state': 0}

# %%
# final model training
ls=Lasso(alpha=.01,random_state=0)
ls.fit(x_train,y_train)
ls_score_training=(ls.score(x_train,y_train))
pred_ls=ls.predict(x_test)
ls_score_training*100
# Out:
# 59.33219991256469

# %%
pred_ls=ls.predict(x_test)

# %%
lss=r2_score(y_test,pred_ls)
lss
# Out:
# 0.5327663894797943

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
parameters={'criterion':['mse','mae'],
            'max_features':["auto","sqrt","log2"]}
           
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'criterion': 'mse', 'max_features': 'sqrt'}

# %%
rf=RandomForestRegressor(criterion='mse',max_features="sqrt")
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor(criterion='mse', max_features='sqrt')

# %%
rf.score(x_train,y_train)
pred_decision=rf.predict(x_test)
rfs=r2_score(y_test,pred_decision)
print("r2_score",rfs*100)
# Out:
# r2_score 81.17397228110133

# %%
#saving the model
import pickle

# %%
pickle.dump(rf,open('power','wb'))

# %%
loaded_model=pickle.load(open('power','rb'))

# %%
result=loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# 81.17397228110133

# %%
#========thank you==================
